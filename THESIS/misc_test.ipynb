# %%
# %matplotlib inline

from collections import defaultdict as ddict, OrderedDict as odict
from typing import Any, Dict, List

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from xgboost import XGBRegressor
from sklearn.neural_network import MLPRegressor
from rdkit.ML.Descriptors.MoleculeDescriptors import MolecularDescriptorCalculator
from rdkit.Chem import PandasTools, AllChem as Chem, Descriptors
from rdkit.Chem.Descriptors import MolWt
from sklearn.ensemble import RandomForestRegressor
import sklearn
from rdkit.Chem.rdmolops import GetFormalCharge
import torch
import torch.nn as nn
import deepchem as dc
import copy
from sklearn.model_selection import train_test_split
from hyperopt import hp
import imp

pd.set_option('display.float_format', lambda x: '%.3f' % x)  # Display floats without scientific notation

# %%
from modules.data import data_maker, Dataset
from modules.RNN import double_RNN
from modules.fit import Model, fit
from modules.myhyperopt import hyperopt_func
from modules.MPNN import double_MPNN
from modules.MP_utils import MolGraph, BatchMolGraph

# %%
import modules

# %%
data = pd.read_csv('data/full_pka_data.csv')
solute = data['Solute SMILES'].tolist()
solvent = data['Solvent SMILES'].tolist()
pka = data['pKa (avg)'].tolist()
data_size = len(solute)

# %%
indices = list(range(data_size))
CV_ids, holdout_ids, _, _ = train_test_split(indices, solvent, test_size=0.2, random_state=1, stratify=solvent)
CV_datasets = data_maker(solute, solvent, pka, CV_ids)
datasets = data_maker(solute, solvent, pka)

# %%
MPNN = Model(name='MPNN',
                model=double_MPNN(atom_messages=True),
                model_type='torch',
                data_type='SMILES')

# %%
def collate_double(batch):
    '''
    Collates double input batches for a torch loader.
        
    Parameters
    ----------
    batch: List = [(X,y)]
        List of (solute,solvent) pairs with their target value.
    
    Returns
    -------
    [sol_batch, solv_batch, targets]: List
        Type of output depends on if the original dataset contains SMILES or sentences.
        Each component is a list / torch.Tensor.
    '''
    if type(batch[0][0][0]) == MolGraph:
        sol_batch = BatchMolGraph([t[0][0] for t in batch])
        solv_batch = BatchMolGraph([t[0][1] for t in batch])
    elif type(batch[0][0][0]) == str:
        sol_batch = [t[0][0] for t in batch]
        solv_batch = [t[0][1] for t in batch]
    else:
        sol_batch = [torch.Tensor(t[0][0]) for t in batch]
        sol_batch = nn.utils.rnn.pad_sequence(sol_batch)
        solv_batch = [torch.Tensor(t[0][1]) for t in batch]
        solv_batch = nn.utils.rnn.pad_sequence(solv_batch)
    targets = torch.Tensor([t[1].item() for t in batch])
    
    return [sol_batch, solv_batch, targets]

def collate_double_s(batch):
    '''
    Collates double input batches for a torch loader.
        
    Parameters
    ----------
    batch: List = [(X,y)]
        List of (solute,solvent) pairs with their target value.
    
    Returns
    -------
    [sol_batch, solv_batch, targets]: List
        Type of output depends on if the original dataset contains SMILES or sentences.
        Each component is a list / torch.Tensor.
    '''
    sol_batch = BatchMolGraph([t[0][0] for t in batch])
    solv_batch = BatchMolGraph([t[0][1] for t in batch])
    targets = torch.Tensor([t[1].item() for t in batch])
    
    return [sol_batch, solv_batch, targets]

def double_loader(data, indices, batch_size=64):
    '''
    torch loader for double inputs.
        
    Parameters
    ----------
    indices : list, np.array
        Indices for selected samples.
    data : List = [(sol,solv),pka]
        Training data of (solute,solvent) pairs and target values.
    batch_size : int
        Size of selected batches
    
    Returns
    -------
    loader : torch.utils.data.DataLoader
        Batched dataloader for torch regressors
    '''
    dataset = Dataset(indices, data[0], data[1])
    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_double)
    return loader

# %%
data = datasets['graphs']
print(type(data[0][0][0])==MolGraph)
# Out:
# True

# %%
def one_run():
    data = datasets['graphs']
    ids = list(range(len(data[0])))
    loader = double_loader(data, ids)
    for (sol,solv,pka) in loader:
        pass
one_run()

# %%
import cProfile

# %%
#graphs
cProfile.run('one_run()', filename=None, sort='cumtime')
# Out:
#          526261 function calls (525290 primitive calls) in 1.447 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.447    1.447 {built-in method builtins.exec}
#         1    0.000    0.000    1.447    1.447 <string>:1(<module>)
#         1    0.059    0.059    1.447    1.447 <ipython-input-34-a9af0a8a3f7f>:1(one_run)
#   1020/51    0.012    0.000    0.702    0.014 module.py:1045(_call_impl)
#        51    0.001    0.000    0.702    0.014 MPNN.py:154(forward)
#        52    0.001    0.000    0.685    0.013 dataloader.py:517(__next__)
#        52    0.001    0.000    0.682    0.013 dataloader.py:559(_next_data)
#        51    0.000    0.000    0.679    0.013 fetch.py:42(fetch)
#       102    0.082    0.001    0.678    0.007 MPNN.py:239(forward)
#        51    0.005    0.000    0.675    0.013 <ipython-input-33-53a2bb97cc48>:31(collate_double)
#       102    0.581    0.006    0.667    0.007 MP_utils.py:235(__init__)
#       459    0.002    0.000    0.140    0.000 linear.py:95(forward)
#       459    0.001    0.000    0.138    0.000 functional.py:1831(linear)
#       459    0.137    0.000    0.137    0.000 {built-in method torch._C._nn.linear}
#       510    0.003    0.000    0.108    0.000 MP_utils.py:348(index_select_ND)
#       357    0.106    0.000    0.106    0.000 {built-in method cat}
#       510    0.099    0.000    0.099    0.000 {method 'index_select' of 'torch._C._TensorBase' objects}
#      6750    0.096    0.000    0.096    0.000 {method 'sum' of 'torch._C._TensorBase' objects}
#       357    0.001    0.000    0.087    0.000 dropout.py:57(forward)
#       357    0.002    0.000    0.086    0.000 functional.py:1151(dropout)
#       357    0.084    0.000    0.084    0.000 {built-in method dropout}
#       408    0.001    0.000    0.035    0.000 functional.py:1287(relu)
#       408    0.034    0.000    0.034    0.000 {built-in method relu}
#       102    0.024    0.000    0.027    0.000 MP_utils.py:275(<listcomp>)
#    270182    0.020    0.000    0.020    0.000 {method 'append' of 'list' objects}
#     50992    0.020    0.000    0.020    0.000 MP_utils.py:259(<listcomp>)
#       204    0.005    0.000    0.017    0.000 {built-in method builtins.max}
#      6444    0.015    0.000    0.015    0.000 {method 'narrow' of 'torch._C._TensorBase' objects}
#     51196    0.009    0.000    0.012    0.000 MP_utils.py:270(<genexpr>)
#        51    0.000    0.000    0.011    0.000 container.py:137(forward)
#       102    0.008    0.000    0.008    0.000 {built-in method stack}
# 105465/105464    0.007    0.000    0.008    0.000 {built-in method builtins.len}
#      1020    0.006    0.000    0.006    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#        51    0.001    0.000    0.004    0.000 fetch.py:44(<listcomp>)
#       102    0.004    0.000    0.004    0.000 MP_utils.py:323(get_a2a)
#      3222    0.004    0.000    0.004    0.000 data.py:205(__getitem__)
#     12888    0.003    0.000    0.003    0.000 {method 'extend' of 'list' objects}
#      1785    0.003    0.000    0.003    0.000 module.py:1117(__getattr__)
#        51    0.001    0.000    0.002    0.000 <ipython-input-33-53a2bb97cc48>:48(<listcomp>)
#      1071    0.002    0.000    0.002    0.000 {built-in method torch._C._get_tracing_state}
#        52    0.000    0.000    0.002    0.000 dataloader.py:511(_next_index)
#        52    0.000    0.000    0.002    0.000 {built-in method builtins.next}
#        52    0.001    0.000    0.002    0.000 sampler.py:224(__iter__)
#      3223    0.002    0.000    0.002    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#       102    0.001    0.000    0.001    0.000 MP_utils.py:281(get_components)
#        52    0.000    0.000    0.001    0.000 profiler.py:613(__enter__)
#      1020    0.001    0.000    0.001    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#        52    0.001    0.000    0.001    0.000 {built-in method torch._ops.profiler._record_function_enter}
#        52    0.000    0.000    0.001    0.000 profiler.py:605(__init__)
#        52    0.000    0.000    0.001    0.000 profiler.py:617(__exit__)
#       357    0.000    0.000    0.001    0.000 _VF.py:25(__getattr__)
#       612    0.001    0.000    0.001    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#        52    0.001    0.000    0.001    0.000 {built-in method zeros}
#        52    0.000    0.000    0.000    0.000 {built-in method torch._ops.profiler._record_function_exit}
#        51    0.000    0.000    0.000    0.000 _tensor.py:585(__len__)
#        51    0.000    0.000    0.000    0.000 <ipython-input-33-53a2bb97cc48>:47(<listcomp>)
#       204    0.000    0.000    0.000    0.000 MP_utils.py:41(get_bond_fdim)
#         1    0.000    0.000    0.000    0.000 dataloader.py:346(__iter__)
#         1    0.000    0.000    0.000    0.000 dataloader.py:300(_get_iterator)
#         1    0.000    0.000    0.000    0.000 dataloader.py:551(__init__)
#        51    0.000    0.000    0.000    0.000 <ipython-input-33-53a2bb97cc48>:46(<listcomp>)
#         1    0.000    0.000    0.000    0.000 dataloader.py:485(__init__)
#       363    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       816    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function_unary}
#       459    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function_variadic}
#         1    0.000    0.000    0.000    0.000 {method 'random_' of 'torch._C._TensorBase' objects}
#        51    0.000    0.000    0.000    0.000 container.py:129(__iter__)
#         1    0.000    0.000    0.000    0.000 <ipython-input-33-53a2bb97cc48>:52(double_loader)
#         1    0.000    0.000    0.000    0.000 dataloader.py:162(__init__)
#       306    0.000    0.000    0.000    0.000 MP_utils.py:32(get_atom_fdim)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 typing.py:1009(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 typing.py:958(_get_protocol_attrs)
#         1    0.000    0.000    0.000    0.000 typing.py:975(_is_callable_members_only)
#        53    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        51    0.000    0.000    0.000    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 dataloader.py:47(create_fetcher)
#        51    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method empty}
#         1    0.000    0.000    0.000    0.000 sampler.py:65(__iter__)
#     19/18    0.000    0.000    0.000    0.000 dataloader.py:336(__setattr__)
#         4    0.000    0.000    0.000    0.000 typing.py:868(__new__)
#        60    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._log_api_usage_once}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        32    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 fetch.py:39(__init__)
#         1    0.000    0.000    0.000    0.000 abc.py:96(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 typing.py:977(<genexpr>)
#         1    0.000    0.000    0.000    0.000 sampler.py:209(__init__)
#         2    0.000    0.000    0.000    0.000 typing.py:1017(<genexpr>)
#         1    0.000    0.000    0.000    0.000 dataloader.py:311(multiprocessing_context)
#         4    0.000    0.000    0.000    0.000 {method 'keys' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 data.py:197(__init__)
#         1    0.000    0.000    0.000    0.000 fetch.py:8(__init__)
#         4    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10ce4a808}
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.000    0.000 data.py:202(__len__)
#         2    0.000    0.000    0.000    0.000 dataloader.py:361(_auto_collation)
#         1    0.000    0.000    0.000    0.000 dataloader.py:406(check_worker_number_rationality)
#         1    0.000    0.000    0.000    0.000 dataloader.py:365(_index_sampler)
#         1    0.000    0.000    0.000    0.000 sampler.py:62(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         4    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.callable}

# %%
#SMILES
cProfile.run('one_run()', filename=None, sort='cumtime')
# Out:
#          2155539 function calls (2154568 primitive calls) in 3.834 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        51    0.001    0.000    0.003    0.000 <ipython-input-12-2e09b19f250d>:1(collate_double)
#        51    0.000    0.000    0.000    0.000 <ipython-input-12-2e09b19f250d>:20(<listcomp>)
#        51    0.000    0.000    0.000    0.000 <ipython-input-12-2e09b19f250d>:21(<listcomp>)
#        51    0.001    0.000    0.002    0.000 <ipython-input-12-2e09b19f250d>:27(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-12-2e09b19f250d>:31(double_loader)
#         1    0.060    0.060    3.834    3.834 <ipython-input-17-11f0fa9c3269>:1(one_run)
#         1    0.000    0.000    3.834    3.834 <string>:1(<module>)
#        51    0.001    0.000    3.760    0.074 MPNN.py:154(forward)
#       102    0.082    0.001    3.736    0.037 MPNN.py:239(forward)
#      6444    0.906    0.000    2.265    0.000 MP_utils.py:130(__init__)
#      6444    0.349    0.000    1.062    0.000 MP_utils.py:147(<listcomp>)
#       102    0.582    0.006    0.695    0.007 MP_utils.py:235(__init__)
#     50992    0.042    0.000    0.042    0.000 MP_utils.py:259(<listcomp>)
#     51196    0.009    0.000    0.012    0.000 MP_utils.py:270(<genexpr>)
#       102    0.028    0.000    0.032    0.000 MP_utils.py:275(<listcomp>)
#       102    0.002    0.000    0.002    0.000 MP_utils.py:281(get_components)
#       306    0.000    0.000    0.000    0.000 MP_utils.py:32(get_atom_fdim)
#       102    0.004    0.000    0.004    0.000 MP_utils.py:323(get_a2a)
#       102    0.059    0.001    3.069    0.030 MP_utils.py:339(mol2graph)
#       102    0.050    0.000    2.315    0.023 MP_utils.py:346(<listcomp>)
#       510    0.004    0.000    0.110    0.000 MP_utils.py:348(index_select_ND)
#       204    0.000    0.000    0.000    0.000 MP_utils.py:41(get_bond_fdim)
#    355111    0.262    0.000    0.332    0.000 MP_utils.py:54(onek_encoding_unk)
#     50992    0.448    0.000    0.713    0.000 MP_utils.py:70(atom_features)
#     49159    0.193    0.000    0.260    0.000 MP_utils.py:91(bond_features)
#       357    0.000    0.000    0.001    0.000 _VF.py:25(__getattr__)
#        51    0.000    0.000    0.000    0.000 _tensor.py:585(__len__)
#         1    0.000    0.000    0.000    0.000 abc.py:96(__instancecheck__)
#        51    0.000    0.000    0.000    0.000 container.py:129(__iter__)
#        51    0.000    0.000    0.011    0.000 container.py:137(forward)
#         1    0.000    0.000    0.000    0.000 data.py:197(__init__)
#         1    0.000    0.000    0.000    0.000 data.py:202(__len__)
#      3222    0.004    0.000    0.004    0.000 data.py:205(__getitem__)
#         1    0.000    0.000    0.000    0.000 dataloader.py:162(__init__)
#         1    0.000    0.000    0.000    0.000 dataloader.py:300(_get_iterator)
#         1    0.000    0.000    0.000    0.000 dataloader.py:311(multiprocessing_context)
#     19/18    0.000    0.000    0.000    0.000 dataloader.py:336(__setattr__)
#         1    0.000    0.000    0.000    0.000 dataloader.py:346(__iter__)
#         2    0.000    0.000    0.000    0.000 dataloader.py:361(_auto_collation)
#         1    0.000    0.000    0.000    0.000 dataloader.py:365(_index_sampler)
#         1    0.000    0.000    0.000    0.000 dataloader.py:406(check_worker_number_rationality)
#         1    0.000    0.000    0.000    0.000 dataloader.py:47(create_fetcher)
#         1    0.000    0.000    0.000    0.000 dataloader.py:485(__init__)
#        52    0.000    0.000    0.002    0.000 dataloader.py:511(_next_index)
#        52    0.001    0.000    0.014    0.000 dataloader.py:517(__next__)
#         1    0.000    0.000    0.000    0.000 dataloader.py:551(__init__)
#        52    0.001    0.000    0.011    0.000 dataloader.py:559(_next_data)
#       357    0.001    0.000    0.081    0.000 dropout.py:57(forward)
#         1    0.000    0.000    0.000    0.000 fetch.py:39(__init__)
#        51    0.000    0.000    0.008    0.000 fetch.py:42(fetch)
#        51    0.001    0.000    0.004    0.000 fetch.py:44(<listcomp>)
#         1    0.000    0.000    0.000    0.000 fetch.py:8(__init__)
#       357    0.002    0.000    0.081    0.000 functional.py:1151(dropout)
#       408    0.001    0.000    0.034    0.000 functional.py:1287(relu)
#       459    0.001    0.000    0.136    0.000 functional.py:1831(linear)
#       459    0.002    0.000    0.139    0.000 linear.py:95(forward)
#   1020/51    0.013    0.000    3.760    0.074 module.py:1045(_call_impl)
#      1785    0.003    0.000    0.003    0.000 module.py:1117(__getattr__)
#        52    0.000    0.000    0.001    0.000 profiler.py:605(__init__)
#        52    0.000    0.000    0.001    0.000 profiler.py:613(__enter__)
#        52    0.000    0.000    0.000    0.000 profiler.py:617(__exit__)
#         1    0.000    0.000    0.000    0.000 sampler.py:209(__init__)
#        52    0.001    0.000    0.002    0.000 sampler.py:224(__iter__)
#         1    0.000    0.000    0.000    0.000 sampler.py:62(__init__)
#         1    0.000    0.000    0.000    0.000 sampler.py:65(__iter__)
#         1    0.000    0.000    0.000    0.000 typing.py:1009(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 typing.py:1017(<genexpr>)
#         4    0.000    0.000    0.000    0.000 typing.py:868(__new__)
#         2    0.000    0.000    0.000    0.000 typing.py:958(_get_protocol_attrs)
#         1    0.000    0.000    0.000    0.000 typing.py:975(_is_callable_members_only)
#         2    0.000    0.000    0.000    0.000 typing.py:977(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10ce4a808}
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    3.834    3.834 {built-in method builtins.exec}
#       363    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        53    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 467020/467019    0.036    0.000    0.036    0.000 {built-in method builtins.len}
#       204    0.005    0.000    0.018    0.000 {built-in method builtins.max}
#        52    0.000    0.000    0.002    0.000 {built-in method builtins.next}
#       357    0.103    0.000    0.103    0.000 {built-in method cat}
#       357    0.078    0.000    0.078    0.000 {built-in method dropout}
#         1    0.000    0.000    0.000    0.000 {built-in method empty}
#       408    0.033    0.000    0.033    0.000 {built-in method relu}
#       102    0.008    0.000    0.008    0.000 {built-in method stack}
#      1071    0.002    0.000    0.002    0.000 {built-in method torch._C._get_tracing_state}
#       816    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function_unary}
#       459    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function_variadic}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._log_api_usage_once}
#       459    0.135    0.000    0.135    0.000 {built-in method torch._C._nn.linear}
#        52    0.001    0.000    0.001    0.000 {built-in method torch._ops.profiler._record_function_enter}
#        52    0.000    0.000    0.000    0.000 {built-in method torch._ops.profiler._record_function_exit}
#        52    0.000    0.000    0.000    0.000 {built-in method zeros}
#        32    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#    714446    0.057    0.000    0.057    0.000 {method 'append' of 'list' objects}
#        51    0.000    0.000    0.000    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     12888    0.003    0.000    0.003    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#    355105    0.043    0.000    0.043    0.000 {method 'index' of 'list' objects}
#       510    0.100    0.000    0.100    0.000 {method 'index_select' of 'torch._C._TensorBase' objects}
#      3223    0.001    0.000    0.001    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#         4    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'keys' of 'mappingproxy' objects}
#      6444    0.016    0.000    0.016    0.000 {method 'narrow' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'random_' of 'torch._C._TensorBase' objects}
#      1020    0.001    0.000    0.001    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#        60    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#      6750    0.091    0.000    0.091    0.000 {method 'sum' of 'torch._C._TensorBase' objects}
#       612    0.001    0.000    0.001    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#        51    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#      1020    0.005    0.000    0.005    0.000 {method 'view' of 'torch._C._TensorBase' objects}
