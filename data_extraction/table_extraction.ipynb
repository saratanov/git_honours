# %%
import tabula
import pandas as pd

# %%
names = [#'a_unified_view_to_bronsted_acidity_scales',
         'Bases_pKa_values_MeCN_DMSO_THF_Water',
         'DCE_2011_pKa_Table_DCE',
#         'ejoc202001649-sup-0001-misc_information',
         'MeCN_Acids_2_Table',
         'MeCN_Bases_2_2005_pKa_table',
         'MeCN_Basicity_pKa_Table_Full',
         'pKa_pH_Acidity_Scale_12-Dichloroethane',
         'pKa_values_of_acids_in_acetonitrile']

# %%
for name in names:
    pdf = 'new_pdfs/'+name+'.pdf'
    csv = name+'.csv'
    tabula.convert_into(pdf,csv, output_format='csv', pages='all')

# %%
name = 'a_unified_view_to_bronsted_acidity_scales'
pdf = 'new_pdfs/'+name+'.pdf'
csv = name+'.csv'
tabula.convert_into(pdf,csv, output_format='csv', pages=[11,12,13])

# %%
name = 'ejoc202001649-sup-0001-misc_information'
pdf = 'new_pdfs/'+name+'.pdf'
csv = name+'.csv'
tabula.convert_into(pdf,csv, output_format='csv', pages=[6,7,8,9,10,11,12])

# %%
tables = tabula.read_pdf('pKa_values_of_acids_in_acetonitrile.pdf')
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.

# %%
df = tables[0]

# %%
df.head()
# Out:
#         Triazine 3  30.86  Unnamed: 0  2.61 Unnamed: 1  Unnamed: 2  \
# 0              NaN    NaN        2.58   NaN        NaN         NaN
# 1     7−NO2−Indole  29.99         NaN   NaN        NaN         NaN
# 2              NaN    NaN         NaN   NaN        NaN         NaN
# 3  Indoxyl acetate  29.97         NaN   NaN        NaN         NaN
# 4           Phenol  29.20         NaN   NaN        NaN         2.1
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  ...  Unnamed: 18  \
# 0         NaN         NaN         NaN         NaN  ...          NaN
# 1         NaN         NaN         NaN         NaN  ...          NaN
# 2         NaN         NaN        0.06         NaN  ...          NaN
# 3         NaN         NaN         NaN         NaN  ...          NaN
# 4         NaN         NaN         NaN         NaN  ...          NaN
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
tabula.convert_into('pKa_values_of_acids_in_acetonitrile.pdf','output.csv', output_format='csv', pages='all')

# %%
data = pd.read_csv('output.csv')

# %%
data.head()
# Out:
#         Triazine 3  30.86
# 0              NaN    NaN
# 1     7−NO2−Indole  29.99
# 2              NaN    NaN
# 3  Indoxyl acetate  29.97
# 4           Phenol  29.20

# %%
data.dropna(inplace=True)

# %%
data.columns = ['mol', 'pka']

# %%
data.head()
# Out:
#                        mol    pka
# 1             7−NO2−Indole  29.99
# 3          Indoxyl acetate  29.97
# 4                   Phenol  29.20
# 5              tBu4Box2CH2  28.85
# 7  4−CN−2,3,5,6−F4−Aniline  28.78

# %%
print(data.to_string())
# Out:
#                                         mol    pka
# 1                              7−NO2−Indole  29.99
# 3                           Indoxyl acetate  29.97
# 4                                    Phenol  29.20
# 5                               tBu4Box2CH2  28.85
# 7                   4−CN−2,3,5,6−F4−Aniline  28.78
# 9                  2,3,4,5,6−(CF3)5−Toluene  28.77
# 11                             5−NO2−Indole  28.18
# 13                          9−C6F5−Fluorene  28.14
# 15       1−(4−Cl−C6H4)−3−(3,4−Cl2−C6H3)urea  27.95
# 16                             4−NO2−Indole  27.89
# 18                             6−NO2−Indole  27.79
# 20                               Me2Box2CH2  27.59
# 22                    (3,5−(CF3)2−C6H3)3COH  27.21
# 24                              C6H5−CH2−Tf  27.19
# 26                 1,2,3,4−F4−9−Ph−Fluorene  27.12
# 28                         4−Cl−C6H4−CH2−Tf  27.06
# 30                          4−F−C6H4−CH2−Tf  27.00
# ...

# %%
data.to_excel("pKa_values_of_acids_in_acetonitrile.xlsx")
