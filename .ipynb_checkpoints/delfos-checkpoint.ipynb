# %%
#delfos copy for pka prediction
import torch
from torch import nn
from mol2vec.features import mol2alt_sentence, mol2sentence, MolSentence, DfVec, sentences2vec
from gensim.models import word2vec
import pandas as pd
from rdkit.Chem import PandasTools
from rdkit import Chem
from numpy import genfromtxt
import numpy as np

# %%
#step 1: define solvent X and solute Y using mol2vec but don't add the substructures!!
#step 2: run RNN in both directions on each molecule, then concatenate forward;reverse to get H and G
#step 3: feed H and G into attention layer, generate attention alignment matrix, create contexts P and Q
#step 4: maxpool H;P and G;Q into 2D feature vectors
#step 5: create flattened input u;v and feed into linear layer

# %%
#step 1: mol2vec embedding

data = pd.read_csv('dwar_pka1.csv')
#data = data.to_numpy()
print(data['SMILES'])
# Out:
# 0       CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...
# 1       CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...
# 2       CC(C)C[C@@H](NC(=O)CNC(=O)[C@@H](NC=O)C(C)C)C(...
# 3       NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)...
# 4       CC(C)C[C@H](NC(=O)[C@@H](CCCNC(N)=O)NC(=O)[C@H...
#                               ...
# 4510               ClC1=CN(CCCCN2CCN(CC2)C2=NC=CC=N2)N=C1
# 4511    [H][C@](N)(CCC(O)=N[C@@]([H])(CS(=O)(=O)CCOP(=...
# 4512    C[N+](C)([O-])CCNC1=CC=C(NCC[N+](C)(C)[O-])C2=...
# 4513    [H][C@@]12CCCN1C(=O)[C@H](CC(C)C)NC(=O)[C@@H](...
# 4514    C[C@@H]1CC2=CC3=C(OCO3)C=C2C(=NN1C(C)=O)C1=CC=...
# Name: SMILES, Length: 4515, dtype: object

# %%
#mol2vec model
mol2vec_model = word2vec.Word2Vec.load('models/model_300dim.pkl')

#create mol type
data['mol'] = data.apply(lambda x: Chem.MolFromSmiles(x['SMILES']), axis=1)

#remove invalid smiles
data.replace("", float("NaN"), inplace=True)
data.dropna(subset = ['mol'], inplace=True)
print(data)

#create sentences
data['sentence'] = data.apply(lambda x: mol2alt_sentence(x['mol'],1), axis=1)

# %%
#modified sentence2vec function to return lists of word vectors
def sentences2vecs(sentences, model, unseen=None):
    """Generate vectors for each word in a sentence sentence (list) in a list of sentences.
    
    Parameters
    ----------
    sentences : list, array
        List with sentences
    model : word2vec.Word2Vec
        Gensim word2vec model
    unseen : None, str
        Keyword for unseen words. If None, those words are skipped.
        https://stats.stackexchange.com/questions/163005/how-to-set-the-dictionary-for-text-analysis-using-neural-networks/163032#163032
    Returns
    -------
    list of arrays, each sentence -> array of word vectors
    """
    keys = set(model.wv.key_to_index)
    bigveclist = []
    if unseen:
        unseen_vec = model.wv.get_vector(unseen)

    for sentence in sentences:
        veclist = []
        if unseen:
            veclist.append([model.wv.get_vector(y) if y in set(sentence) & keys
                       else unseen_vec for y in sentence])
        else:
            veclist.append([model.wv.get_vector(y) for y in sentence 
                            if y in set(sentence) & keys])
        vecarray = np.concatenate(veclist, axis=1)
        vectensor = torch.Tensor(vecarray)
        bigveclist.append(vectensor)
    return bigveclist

# %%
sentences = [x for x in data['sentence']]
targets = torch.Tensor(data['JCHEM_PKA'])
X = sentences2vecs(sentences, model, unseen='UNK')

# %%
solvent = {'SMILES': ['CC#N','C1CCOC1','CS(C)=O','C1=CC=CC=C1']}
solvent = pd.DataFrame(solvent)
solvent['mol'] = solvent.apply(lambda x: Chem.MolFromSmiles(x['SMILES']), axis=1)
solvent['sentence'] = solvent.apply(lambda x: mol2alt_sentence(x['mol'],1), axis=1)
solvent = [x for x in solvent['sentence']]
Y = sentences2vecs(solvent, model, unseen='UNK')

# %%
print(Y[2].size())
# Out:
# torch.Size([8, 300])

# %%
#from torch.nn.utils.rnn import pack_sequence
#X = pack_sequence(X,enforce_sorted = False)

# %%
def att(g,h):
    a = torch.exp(torch.dot(g,h))
    return a

def alpha(G,H):
    n = H.shape[0]
    m = G.shape[0]
    alpha = [[att(H[i],G[j])/sum([att(H[i],G[k]) for k in range(m)]) for j in range(m)] for i in range(n)]
    #change this
    return torch.Tensor(alpha)

def batch_att(G,H):
    P = alpha(G,H)@G
    inG = torch.cat((G,Q),1)
    return inG

# %%
G = torch.rand(5,2)
H = torch.rand(3,2)
alphaG = alpha(G,H)
alphaH = alpha(H,G)
print(alphaG)
# Out:
# tensor([[0.1881, 0.2322, 0.2151, 0.0970, 0.2676],
#         [0.1669, 0.2218, 0.2314, 0.1666, 0.2133],
#         [0.2078, 0.2056, 0.1989, 0.1712, 0.2165]])

# %%
# model definition
epochs = 10
n_features = 300
n_hidden = 100

class maxpool(nn.Module):
    def __init__(self, L):
        super(maxpool, self).__init__()
        self.maxpool = nn.MaxPool2d((L,2), stride=2)
    def forward(self, X):
        return self.maxpool(X)

class dnet(nn.Module):
    def __init__(self, n_features, D, FF):
        super(dnet, self).__init__()
    
        self.biLSTM_X = nn.LSTM(n_features, D, bidirectional=True)
        self.biLSTM_Y = nn.LSTM(n_features, D, bidirectional=True)
        
        self.FF = nn.Linear(4*D, FF)
        self.out = nn.Linear(FF, 1)
    
    def forward(self,X,Y):
        N = X.data.shape[0]
        M = Y.data.shape[0]
        
        #turn input list of vec into correct shape
        X = X.view(X.data.shape[0],1,X.data.shape[1]) #N rows
        Y = Y.view(Y.data.shape[0],1,Y.data.shape[1]) #M rows
        
        #biLSTM to get hidden states
        H, hcX = self.biLSTM_X(X, None) #Nx1x2D matrix
        G, hcY = self.biLSTM_Y(Y, None) #Mx1x2D matrix
        
        G = G.view(G.data.shape[0],G.data.shape[2]) #N rows
        H = H.view(H.data.shape[0],H.data.shape[2]) #M rows
        #solvent (P) and solute (Q) context
        alphaG = alpha(G, H)   #NxM tensor
        P = alphaG@G           #Nx2D tensor
        alphaH = alpha(H, G)   #MxN tensor
        Q = alphaH@H           #Mx2D tensor
        inG = torch.cat((G,Q),1) #Nx4D
        inH = torch.cat((H,P),1) #Mx4D
        
        #maxpool concatenated tensors
        maxpool_X = maxpool(N)
        maxpool_Y = maxpool(M)
        u = maxpool_X(inH.view(1,inH.data.shape[0],inH.data.shape[1]))  #1x1x2D
        v = maxpool_Y(inG.view(1,inG.data.shape[0],inG.data.shape[1]))  #1x1x2D
        
        #feed forward neural network
        NN = torch.cat((u,v),2)
        NN = self.FF(NN)
        NN = nn.functional.relu(NN)
        output = self.out(NN)
        return output

dmodel = dnet(300,150,2000)
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(dmodel.parameters(), lr=0.0002, momentum=0.9, nesterov=True)

# %%
dmodel(X[2],Y[0])

# %%
epochs = 10
n_features = 300
n_hidden = 100

for t in range(epochs):
    for b in range(len(X)):
        solute = X[b]
        solvent = Y[0]
        target = targets[b]  

        output = dmodel(solute,solvent) 
        print(output)
        loss = criterion(output, target)  
        
        loss.backward()
        optimizer.step()        
        optimizer.zero_grad() 
    print('step : ' , t , 'loss : ' , loss.item())
# Out:
# tensor([[[-0.0335]]], grad_fn=<AddBackward0>)
# /Users/u6676643/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([])) that is different to the input size (torch.Size([1, 1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# tensor([[[-0.0174]]], grad_fn=<AddBackward0>)
# tensor([[[0.0331]]], grad_fn=<AddBackward0>)
# tensor([[[0.1142]]], grad_fn=<AddBackward0>)
# tensor([[[0.2067]]], grad_fn=<AddBackward0>)
# tensor([[[0.3410]]], grad_fn=<AddBackward0>)
# tensor([[[0.4313]]], grad_fn=<AddBackward0>)
# tensor([[[0.5649]]], grad_fn=<AddBackward0>)
# tensor([[[0.7295]]], grad_fn=<AddBackward0>)
# tensor([[[0.8763]]], grad_fn=<AddBackward0>)
# tensor([[[1.0472]]], grad_fn=<AddBackward0>)
# tensor([[[1.3815]]], grad_fn=<AddBackward0>)
# tensor([[[1.4849]]], grad_fn=<AddBackward0>)
# tensor([[[1.5701]]], grad_fn=<AddBackward0>)
# tensor([[[1.9725]]], grad_fn=<AddBackward0>)
# tensor([[[1.9300]]], grad_fn=<AddBackward0>)
# tensor([[[2.3562]]], grad_fn=<AddBackward0>)
# tensor([[[2.9146]]], grad_fn=<AddBackward0>)
# tensor([[[3.0545]]], grad_fn=<AddBackward0>)
# tensor([[[3.6253]]], grad_fn=<AddBackward0>)
# tensor([[[4.1609]]], grad_fn=<AddBackward0>)
# tensor([[[4.7093]]], grad_fn=<AddBackward0>)
# tensor([[[5.1099]]], grad_fn=<AddBackward0>)
# tensor([[[5.9978]]], grad_fn=<AddBackward0>)
# tensor([[[7.2826]]], grad_fn=<AddBackward0>)
# tensor([[[7.9112]]], grad_fn=<AddBackward0>)
# tensor([[[8.8790]]], grad_fn=<AddBackward0>)
# tensor([[[9.5901]]], grad_fn=<AddBackward0>)
# tensor([[[10.0140]]], grad_fn=<AddBackward0>)
# tensor([[[10.4964]]], grad_fn=<AddBackward0>)
# tensor([[[10.4357]]], grad_fn=<AddBackward0>)
# tensor([[[10.7672]]], grad_fn=<AddBackward0>)
# tensor([[[11.1461]]], grad_fn=<AddBackward0>)
# tensor([[[11.4052]]], grad_fn=<AddBackward0>)
# tensor([[[11.4278]]], grad_fn=<AddBackward0>)
# tensor([[[12.4851]]], grad_fn=<AddBackward0>)
# tensor([[[13.4914]]], grad_fn=<AddBackward0>)
# tensor([[[13.9532]]], grad_fn=<AddBackward0>)
# tensor([[[15.1150]]], grad_fn=<AddBackward0>)
# tensor([[[14.7307]]], grad_fn=<AddBackward0>)
# tensor([[[12.1883]]], grad_fn=<AddBackward0>)
# tensor([[[13.5130]]], grad_fn=<AddBackward0>)
# tensor([[[11.7991]]], grad_fn=<AddBackward0>)
# tensor([[[11.1202]]], grad_fn=<AddBackward0>)
# tensor([[[10.6170]]], grad_fn=<AddBackward0>)
# tensor([[[10.5290]]], grad_fn=<AddBackward0>)
# tensor([[[9.9983]]], grad_fn=<AddBackward0>)
# tensor([[[10.2812]]], grad_fn=<AddBackward0>)
# tensor([[[11.0541]]], grad_fn=<AddBackward0>)
# tensor([[[10.6107]]], grad_fn=<AddBackward0>)
# tensor([[[10.0411]]], grad_fn=<AddBackward0>)
# tensor([[[10.1701]]], grad_fn=<AddBackward0>)
# tensor([[[11.5607]]], grad_fn=<AddBackward0>)
# tensor([[[10.7617]]], grad_fn=<AddBackward0>)
# tensor([[[11.3711]]], grad_fn=<AddBackward0>)
# tensor([[[10.4653]]], grad_fn=<AddBackward0>)
# tensor([[[10.8239]]], grad_fn=<AddBackward0>)
# tensor([[[11.8243]]], grad_fn=<AddBackward0>)
# tensor([[[11.7060]]], grad_fn=<AddBackward0>)
# tensor([[[11.3560]]], grad_fn=<AddBackward0>)
# tensor([[[12.1390]]], grad_fn=<AddBackward0>)
# tensor([[[12.1855]]], grad_fn=<AddBackward0>)
# tensor([[[12.7964]]], grad_fn=<AddBackward0>)
# tensor([[[14.4040]]], grad_fn=<AddBackward0>)
# tensor([[[12.6664]]], grad_fn=<AddBackward0>)
# tensor([[[14.2331]]], grad_fn=<AddBackward0>)
# tensor([[[12.3533]]], grad_fn=<AddBackward0>)
# tensor([[[12.1055]]], grad_fn=<AddBackward0>)
# tensor([[[12.7081]]], grad_fn=<AddBackward0>)
# tensor([[[13.3288]]], grad_fn=<AddBackward0>)
# tensor([[[12.7805]]], grad_fn=<AddBackward0>)
# tensor([[[12.5074]]], grad_fn=<AddBackward0>)
# tensor([[[12.4394]]], grad_fn=<AddBackward0>)
# tensor([[[11.7245]]], grad_fn=<AddBackward0>)
# tensor([[[13.1072]]], grad_fn=<AddBackward0>)
# tensor([[[12.2345]]], grad_fn=<AddBackward0>)
# tensor([[[12.2000]]], grad_fn=<AddBackward0>)
# tensor([[[13.6581]]], grad_fn=<AddBackward0>)
# tensor([[[12.6435]]], grad_fn=<AddBackward0>)
# tensor([[[14.1585]]], grad_fn=<AddBackward0>)
# tensor([[[14.5728]]], grad_fn=<AddBackward0>)
# tensor([[[15.1766]]], grad_fn=<AddBackward0>)
# tensor([[[16.5463]]], grad_fn=<AddBackward0>)
# tensor([[[15.5339]]], grad_fn=<AddBackward0>)
# tensor([[[14.4498]]], grad_fn=<AddBackward0>)
# tensor([[[12.4570]]], grad_fn=<AddBackward0>)
# tensor([[[13.2311]]], grad_fn=<AddBackward0>)
# tensor([[[12.3332]]], grad_fn=<AddBackward0>)
# tensor([[[12.2828]]], grad_fn=<AddBackward0>)
# tensor([[[11.8635]]], grad_fn=<AddBackward0>)
# tensor([[[11.1479]]], grad_fn=<AddBackward0>)
# tensor([[[11.2198]]], grad_fn=<AddBackward0>)
# tensor([[[10.6923]]], grad_fn=<AddBackward0>)
# tensor([[[11.2675]]], grad_fn=<AddBackward0>)
# tensor([[[11.7741]]], grad_fn=<AddBackward0>)
# tensor([[[8.9995]]], grad_fn=<AddBackward0>)
# tensor([[[9.5372]]], grad_fn=<AddBackward0>)
# tensor([[[8.6770]]], grad_fn=<AddBackward0>)
# tensor([[[8.4601]]], grad_fn=<AddBackward0>)
# tensor([[[8.5277]]], grad_fn=<AddBackward0>)
# tensor([[[9.3595]]], grad_fn=<AddBackward0>)
# tensor([[[9.8454]]], grad_fn=<AddBackward0>)
# tensor([[[8.7219]]], grad_fn=<AddBackward0>)
# tensor([[[10.0484]]], grad_fn=<AddBackward0>)
# tensor([[[10.1693]]], grad_fn=<AddBackward0>)
# tensor([[[11.2463]]], grad_fn=<AddBackward0>)
# tensor([[[12.1275]]], grad_fn=<AddBackward0>)
# tensor([[[11.8109]]], grad_fn=<AddBackward0>)
# tensor([[[11.5644]]], grad_fn=<AddBackward0>)
# tensor([[[12.5341]]], grad_fn=<AddBackward0>)
# tensor([[[12.7834]]], grad_fn=<AddBackward0>)
# tensor([[[12.6481]]], grad_fn=<AddBackward0>)
# tensor([[[13.3414]]], grad_fn=<AddBackward0>)
# tensor([[[14.0675]]], grad_fn=<AddBackward0>)
# tensor([[[14.0254]]], grad_fn=<AddBackward0>)
# tensor([[[14.0652]]], grad_fn=<AddBackward0>)
# tensor([[[14.7402]]], grad_fn=<AddBackward0>)
# tensor([[[14.8813]]], grad_fn=<AddBackward0>)
# tensor([[[14.3416]]], grad_fn=<AddBackward0>)
# tensor([[[14.0133]]], grad_fn=<AddBackward0>)
# tensor([[[13.9030]]], grad_fn=<AddBackward0>)
# tensor([[[13.0934]]], grad_fn=<AddBackward0>)
# tensor([[[14.1158]]], grad_fn=<AddBackward0>)
# tensor([[[13.9346]]], grad_fn=<AddBackward0>)
# tensor([[[14.1613]]], grad_fn=<AddBackward0>)
# tensor([[[14.7735]]], grad_fn=<AddBackward0>)
# tensor([[[14.2108]]], grad_fn=<AddBackward0>)
# tensor([[[15.5410]]], grad_fn=<AddBackward0>)
# tensor([[[15.2739]]], grad_fn=<AddBackward0>)
# tensor([[[16.5229]]], grad_fn=<AddBackward0>)
# tensor([[[17.9793]]], grad_fn=<AddBackward0>)
# tensor([[[17.3933]]], grad_fn=<AddBackward0>)
# tensor([[[17.8315]]], grad_fn=<AddBackward0>)
# tensor([[[17.7057]]], grad_fn=<AddBackward0>)
# tensor([[[15.9133]]], grad_fn=<AddBackward0>)
# tensor([[[15.3221]]], grad_fn=<AddBackward0>)
# tensor([[[13.6231]]], grad_fn=<AddBackward0>)
# tensor([[[12.0559]]], grad_fn=<AddBackward0>)
# tensor([[[12.7266]]], grad_fn=<AddBackward0>)
# tensor([[[12.2585]]], grad_fn=<AddBackward0>)
# tensor([[[12.2906]]], grad_fn=<AddBackward0>)
# tensor([[[12.3684]]], grad_fn=<AddBackward0>)
# tensor([[[12.0838]]], grad_fn=<AddBackward0>)
# tensor([[[10.7735]]], grad_fn=<AddBackward0>)
# tensor([[[12.1626]]], grad_fn=<AddBackward0>)
# tensor([[[11.1402]]], grad_fn=<AddBackward0>)
# tensor([[[12.4844]]], grad_fn=<AddBackward0>)
# tensor([[[13.1727]]], grad_fn=<AddBackward0>)
# tensor([[[11.9744]]], grad_fn=<AddBackward0>)
# tensor([[[13.9401]]], grad_fn=<AddBackward0>)
# tensor([[[12.3082]]], grad_fn=<AddBackward0>)
# tensor([[[13.1843]]], grad_fn=<AddBackward0>)
# tensor([[[13.6976]]], grad_fn=<AddBackward0>)
# tensor([[[13.7083]]], grad_fn=<AddBackward0>)
# tensor([[[12.4030]]], grad_fn=<AddBackward0>)
# tensor([[[12.7451]]], grad_fn=<AddBackward0>)
# tensor([[[12.5100]]], grad_fn=<AddBackward0>)
# tensor([[[13.1657]]], grad_fn=<AddBackward0>)
# tensor([[[12.9949]]], grad_fn=<AddBackward0>)
# tensor([[[12.2807]]], grad_fn=<AddBackward0>)
# tensor([[[13.8217]]], grad_fn=<AddBackward0>)
# tensor([[[13.0283]]], grad_fn=<AddBackward0>)
# tensor([[[12.3935]]], grad_fn=<AddBackward0>)
# tensor([[[13.2750]]], grad_fn=<AddBackward0>)
# tensor([[[12.9569]]], grad_fn=<AddBackward0>)
# tensor([[[13.1100]]], grad_fn=<AddBackward0>)
# tensor([[[13.7606]]], grad_fn=<AddBackward0>)
# tensor([[[13.8586]]], grad_fn=<AddBackward0>)
# tensor([[[13.0593]]], grad_fn=<AddBackward0>)
# tensor([[[12.3730]]], grad_fn=<AddBackward0>)
# tensor([[[11.4228]]], grad_fn=<AddBackward0>)
# tensor([[[12.9579]]], grad_fn=<AddBackward0>)
# tensor([[[11.9480]]], grad_fn=<AddBackward0>)
# tensor([[[12.4774]]], grad_fn=<AddBackward0>)
# tensor([[[12.1146]]], grad_fn=<AddBackward0>)
# tensor([[[12.9548]]], grad_fn=<AddBackward0>)
# tensor([[[11.9639]]], grad_fn=<AddBackward0>)
# tensor([[[13.6485]]], grad_fn=<AddBackward0>)
# tensor([[[12.1388]]], grad_fn=<AddBackward0>)
# tensor([[[13.5148]]], grad_fn=<AddBackward0>)
# tensor([[[13.3456]]], grad_fn=<AddBackward0>)
# tensor([[[12.1023]]], grad_fn=<AddBackward0>)
# tensor([[[14.0907]]], grad_fn=<AddBackward0>)
# tensor([[[11.7635]]], grad_fn=<AddBackward0>)
# tensor([[[11.0500]]], grad_fn=<AddBackward0>)
# tensor([[[11.8276]]], grad_fn=<AddBackward0>)
# tensor([[[12.0853]]], grad_fn=<AddBackward0>)
# tensor([[[11.3288]]], grad_fn=<AddBackward0>)
# tensor([[[11.4107]]], grad_fn=<AddBackward0>)
# tensor([[[11.9663]]], grad_fn=<AddBackward0>)
# tensor([[[11.7062]]], grad_fn=<AddBackward0>)
# tensor([[[12.9408]]], grad_fn=<AddBackward0>)
# tensor([[[13.2117]]], grad_fn=<AddBackward0>)
# tensor([[[13.5381]]], grad_fn=<AddBackward0>)
# tensor([[[13.4365]]], grad_fn=<AddBackward0>)
# tensor([[[14.6572]]], grad_fn=<AddBackward0>)
# tensor([[[15.0372]]], grad_fn=<AddBackward0>)
# tensor([[[14.7440]]], grad_fn=<AddBackward0>)
# tensor([[[14.2107]]], grad_fn=<AddBackward0>)
# tensor([[[13.5999]]], grad_fn=<AddBackward0>)
# tensor([[[13.6453]]], grad_fn=<AddBackward0>)
# tensor([[[13.5548]]], grad_fn=<AddBackward0>)
# tensor([[[12.7302]]], grad_fn=<AddBackward0>)
# tensor([[[13.2205]]], grad_fn=<AddBackward0>)
# tensor([[[14.0099]]], grad_fn=<AddBackward0>)
# tensor([[[13.7585]]], grad_fn=<AddBackward0>)
# tensor([[[14.5600]]], grad_fn=<AddBackward0>)
# tensor([[[12.9848]]], grad_fn=<AddBackward0>)
# tensor([[[12.1119]]], grad_fn=<AddBackward0>)
# tensor([[[12.3418]]], grad_fn=<AddBackward0>)
# tensor([[[12.3526]]], grad_fn=<AddBackward0>)
# tensor([[[12.8377]]], grad_fn=<AddBackward0>)
# tensor([[[11.9898]]], grad_fn=<AddBackward0>)
# tensor([[[10.9774]]], grad_fn=<AddBackward0>)
# tensor([[[10.8956]]], grad_fn=<AddBackward0>)
# tensor([[[10.0166]]], grad_fn=<AddBackward0>)
# tensor([[[9.7815]]], grad_fn=<AddBackward0>)
# tensor([[[8.8777]]], grad_fn=<AddBackward0>)
# tensor([[[9.8725]]], grad_fn=<AddBackward0>)
# tensor([[[9.6320]]], grad_fn=<AddBackward0>)
# tensor([[[9.7362]]], grad_fn=<AddBackward0>)
# tensor([[[9.8250]]], grad_fn=<AddBackward0>)
# tensor([[[10.1590]]], grad_fn=<AddBackward0>)
# tensor([[[10.3698]]], grad_fn=<AddBackward0>)
# tensor([[[10.8772]]], grad_fn=<AddBackward0>)
# tensor([[[10.9046]]], grad_fn=<AddBackward0>)
# tensor([[[11.6317]]], grad_fn=<AddBackward0>)
# tensor([[[12.1000]]], grad_fn=<AddBackward0>)
# tensor([[[13.5927]]], grad_fn=<AddBackward0>)
# tensor([[[13.6647]]], grad_fn=<AddBackward0>)
# tensor([[[12.6177]]], grad_fn=<AddBackward0>)
# tensor([[[13.1200]]], grad_fn=<AddBackward0>)
# tensor([[[12.7606]]], grad_fn=<AddBackward0>)
# tensor([[[13.3508]]], grad_fn=<AddBackward0>)
# tensor([[[12.7491]]], grad_fn=<AddBackward0>)
# tensor([[[11.9060]]], grad_fn=<AddBackward0>)
# tensor([[[10.5477]]], grad_fn=<AddBackward0>)
# tensor([[[10.6384]]], grad_fn=<AddBackward0>)
# tensor([[[8.8158]]], grad_fn=<AddBackward0>)
# tensor([[[8.9125]]], grad_fn=<AddBackward0>)
# tensor([[[8.2682]]], grad_fn=<AddBackward0>)
# tensor([[[9.1435]]], grad_fn=<AddBackward0>)
# tensor([[[9.4329]]], grad_fn=<AddBackward0>)
# tensor([[[9.0852]]], grad_fn=<AddBackward0>)
# tensor([[[10.4148]]], grad_fn=<AddBackward0>)
# tensor([[[10.3931]]], grad_fn=<AddBackward0>)
# tensor([[[11.8898]]], grad_fn=<AddBackward0>)
# tensor([[[10.3653]]], grad_fn=<AddBackward0>)
# tensor([[[11.4883]]], grad_fn=<AddBackward0>)
# tensor([[[11.5995]]], grad_fn=<AddBackward0>)
# tensor([[[10.9053]]], grad_fn=<AddBackward0>)
# tensor([[[12.1701]]], grad_fn=<AddBackward0>)
# tensor([[[12.6019]]], grad_fn=<AddBackward0>)
# tensor([[[13.2825]]], grad_fn=<AddBackward0>)
# tensor([[[12.7877]]], grad_fn=<AddBackward0>)
# tensor([[[14.7103]]], grad_fn=<AddBackward0>)
# tensor([[[14.3996]]], grad_fn=<AddBackward0>)
# tensor([[[14.9102]]], grad_fn=<AddBackward0>)
# tensor([[[15.5974]]], grad_fn=<AddBackward0>)
# tensor([[[15.0334]]], grad_fn=<AddBackward0>)
# tensor([[[15.7342]]], grad_fn=<AddBackward0>)
# tensor([[[14.6360]]], grad_fn=<AddBackward0>)
# tensor([[[14.5930]]], grad_fn=<AddBackward0>)
# tensor([[[13.9065]]], grad_fn=<AddBackward0>)
# tensor([[[13.8890]]], grad_fn=<AddBackward0>)
# tensor([[[14.1475]]], grad_fn=<AddBackward0>)
# tensor([[[12.7796]]], grad_fn=<AddBackward0>)
# tensor([[[12.0661]]], grad_fn=<AddBackward0>)
# tensor([[[10.7126]]], grad_fn=<AddBackward0>)
# tensor([[[10.7008]]], grad_fn=<AddBackward0>)
# tensor([[[10.2713]]], grad_fn=<AddBackward0>)
# tensor([[[9.8705]]], grad_fn=<AddBackward0>)
# tensor([[[10.3105]]], grad_fn=<AddBackward0>)
# tensor([[[9.0079]]], grad_fn=<AddBackward0>)
# tensor([[[9.6917]]], grad_fn=<AddBackward0>)
# tensor([[[8.9028]]], grad_fn=<AddBackward0>)
# tensor([[[10.0401]]], grad_fn=<AddBackward0>)
# tensor([[[9.4476]]], grad_fn=<AddBackward0>)
# tensor([[[9.2032]]], grad_fn=<AddBackward0>)
# tensor([[[9.7983]]], grad_fn=<AddBackward0>)
# tensor([[[9.9652]]], grad_fn=<AddBackward0>)
# tensor([[[9.5917]]], grad_fn=<AddBackward0>)
# tensor([[[10.4474]]], grad_fn=<AddBackward0>)
# tensor([[[10.9121]]], grad_fn=<AddBackward0>)
# tensor([[[11.9999]]], grad_fn=<AddBackward0>)
# tensor([[[11.8948]]], grad_fn=<AddBackward0>)
# tensor([[[12.0870]]], grad_fn=<AddBackward0>)
# tensor([[[12.7186]]], grad_fn=<AddBackward0>)
# tensor([[[13.2700]]], grad_fn=<AddBackward0>)
# tensor([[[13.4255]]], grad_fn=<AddBackward0>)
# tensor([[[13.5665]]], grad_fn=<AddBackward0>)
# tensor([[[14.1134]]], grad_fn=<AddBackward0>)
# tensor([[[14.1112]]], grad_fn=<AddBackward0>)
# tensor([[[15.8987]]], grad_fn=<AddBackward0>)
# tensor([[[14.4455]]], grad_fn=<AddBackward0>)
# tensor([[[15.6266]]], grad_fn=<AddBackward0>)
# tensor([[[16.0069]]], grad_fn=<AddBackward0>)
# tensor([[[14.0711]]], grad_fn=<AddBackward0>)
# tensor([[[13.5563]]], grad_fn=<AddBackward0>)
# tensor([[[14.3085]]], grad_fn=<AddBackward0>)
# tensor([[[13.9397]]], grad_fn=<AddBackward0>)
# tensor([[[11.9558]]], grad_fn=<AddBackward0>)
# tensor([[[11.3889]]], grad_fn=<AddBackward0>)
# tensor([[[10.5917]]], grad_fn=<AddBackward0>)
# tensor([[[11.3775]]], grad_fn=<AddBackward0>)
# tensor([[[11.2222]]], grad_fn=<AddBackward0>)
# tensor([[[10.9882]]], grad_fn=<AddBackward0>)
# tensor([[[10.8048]]], grad_fn=<AddBackward0>)
# tensor([[[11.0155]]], grad_fn=<AddBackward0>)
# tensor([[[10.7714]]], grad_fn=<AddBackward0>)
# tensor([[[11.0880]]], grad_fn=<AddBackward0>)
# tensor([[[10.7451]]], grad_fn=<AddBackward0>)
# tensor([[[10.8223]]], grad_fn=<AddBackward0>)
# tensor([[[10.5034]]], grad_fn=<AddBackward0>)
# tensor([[[10.3338]]], grad_fn=<AddBackward0>)
# tensor([[[10.5499]]], grad_fn=<AddBackward0>)
# tensor([[[9.6621]]], grad_fn=<AddBackward0>)
# tensor([[[9.7684]]], grad_fn=<AddBackward0>)
# tensor([[[10.3011]]], grad_fn=<AddBackward0>)
# tensor([[[10.3471]]], grad_fn=<AddBackward0>)
# tensor([[[9.7088]]], grad_fn=<AddBackward0>)
# tensor([[[10.7686]]], grad_fn=<AddBackward0>)
# tensor([[[10.6641]]], grad_fn=<AddBackward0>)
# tensor([[[10.4372]]], grad_fn=<AddBackward0>)
# tensor([[[9.4952]]], grad_fn=<AddBackward0>)
# tensor([[[12.0638]]], grad_fn=<AddBackward0>)
# tensor([[[11.6792]]], grad_fn=<AddBackward0>)
# tensor([[[13.9100]]], grad_fn=<AddBackward0>)
# tensor([[[13.9454]]], grad_fn=<AddBackward0>)
# tensor([[[13.0322]]], grad_fn=<AddBackward0>)
# tensor([[[14.0115]]], grad_fn=<AddBackward0>)
# tensor([[[14.1024]]], grad_fn=<AddBackward0>)
# tensor([[[14.7459]]], grad_fn=<AddBackward0>)
# tensor([[[14.1281]]], grad_fn=<AddBackward0>)
# tensor([[[14.2942]]], grad_fn=<AddBackward0>)
# tensor([[[13.5361]]], grad_fn=<AddBackward0>)
# tensor([[[13.5861]]], grad_fn=<AddBackward0>)
# tensor([[[13.0532]]], grad_fn=<AddBackward0>)
# tensor([[[12.7295]]], grad_fn=<AddBackward0>)
# tensor([[[12.3946]]], grad_fn=<AddBackward0>)
# tensor([[[12.4398]]], grad_fn=<AddBackward0>)
# tensor([[[13.6894]]], grad_fn=<AddBackward0>)
# tensor([[[13.5218]]], grad_fn=<AddBackward0>)
# tensor([[[12.5196]]], grad_fn=<AddBackward0>)
# tensor([[[13.0669]]], grad_fn=<AddBackward0>)
# tensor([[[14.0813]]], grad_fn=<AddBackward0>)
# tensor([[[13.4562]]], grad_fn=<AddBackward0>)
# tensor([[[12.4203]]], grad_fn=<AddBackward0>)
# tensor([[[13.4930]]], grad_fn=<AddBackward0>)
# tensor([[[13.7696]]], grad_fn=<AddBackward0>)
# tensor([[[11.3993]]], grad_fn=<AddBackward0>)
# tensor([[[13.3335]]], grad_fn=<AddBackward0>)
# tensor([[[11.2598]]], grad_fn=<AddBackward0>)
# tensor([[[11.2193]]], grad_fn=<AddBackward0>)
# tensor([[[10.0843]]], grad_fn=<AddBackward0>)
# tensor([[[11.0682]]], grad_fn=<AddBackward0>)
# tensor([[[9.5647]]], grad_fn=<AddBackward0>)
# tensor([[[9.8869]]], grad_fn=<AddBackward0>)
# tensor([[[9.2854]]], grad_fn=<AddBackward0>)
# tensor([[[9.7071]]], grad_fn=<AddBackward0>)
# tensor([[[10.1046]]], grad_fn=<AddBackward0>)
# tensor([[[9.4963]]], grad_fn=<AddBackward0>)
# tensor([[[9.8730]]], grad_fn=<AddBackward0>)
# tensor([[[10.6519]]], grad_fn=<AddBackward0>)
# tensor([[[10.3749]]], grad_fn=<AddBackward0>)
# tensor([[[10.3540]]], grad_fn=<AddBackward0>)
# tensor([[[10.3961]]], grad_fn=<AddBackward0>)
# tensor([[[11.3911]]], grad_fn=<AddBackward0>)
# tensor([[[13.1859]]], grad_fn=<AddBackward0>)
# tensor([[[11.7341]]], grad_fn=<AddBackward0>)
# tensor([[[12.1545]]], grad_fn=<AddBackward0>)
# tensor([[[12.2656]]], grad_fn=<AddBackward0>)
# tensor([[[13.9111]]], grad_fn=<AddBackward0>)
# tensor([[[13.1983]]], grad_fn=<AddBackward0>)
# tensor([[[15.8480]]], grad_fn=<AddBackward0>)
# tensor([[[15.0509]]], grad_fn=<AddBackward0>)
# tensor([[[14.2706]]], grad_fn=<AddBackward0>)
# tensor([[[13.4319]]], grad_fn=<AddBackward0>)
# tensor([[[14.5047]]], grad_fn=<AddBackward0>)
# tensor([[[14.3983]]], grad_fn=<AddBackward0>)
# tensor([[[14.7732]]], grad_fn=<AddBackward0>)
# tensor([[[15.6974]]], grad_fn=<AddBackward0>)
# tensor([[[15.0820]]], grad_fn=<AddBackward0>)
# tensor([[[14.2874]]], grad_fn=<AddBackward0>)
# tensor([[[15.1761]]], grad_fn=<AddBackward0>)
# tensor([[[13.4987]]], grad_fn=<AddBackward0>)
# tensor([[[13.6127]]], grad_fn=<AddBackward0>)
# tensor([[[11.7510]]], grad_fn=<AddBackward0>)
# tensor([[[12.0462]]], grad_fn=<AddBackward0>)
# tensor([[[10.8489]]], grad_fn=<AddBackward0>)
# tensor([[[10.8650]]], grad_fn=<AddBackward0>)
# tensor([[[9.8689]]], grad_fn=<AddBackward0>)
# tensor([[[9.9635]]], grad_fn=<AddBackward0>)
# tensor([[[8.9962]]], grad_fn=<AddBackward0>)
# tensor([[[9.2831]]], grad_fn=<AddBackward0>)
# tensor([[[8.4596]]], grad_fn=<AddBackward0>)
# tensor([[[8.5333]]], grad_fn=<AddBackward0>)
# tensor([[[8.9858]]], grad_fn=<AddBackward0>)
# tensor([[[10.5381]]], grad_fn=<AddBackward0>)
# tensor([[[11.2948]]], grad_fn=<AddBackward0>)
# tensor([[[9.9779]]], grad_fn=<AddBackward0>)
# tensor([[[10.9959]]], grad_fn=<AddBackward0>)
# tensor([[[10.2607]]], grad_fn=<AddBackward0>)
# tensor([[[12.3844]]], grad_fn=<AddBackward0>)
# tensor([[[11.3487]]], grad_fn=<AddBackward0>)
# tensor([[[12.8546]]], grad_fn=<AddBackward0>)
# tensor([[[13.7911]]], grad_fn=<AddBackward0>)
# tensor([[[12.2163]]], grad_fn=<AddBackward0>)
# tensor([[[11.7000]]], grad_fn=<AddBackward0>)
# tensor([[[13.0028]]], grad_fn=<AddBackward0>)
# tensor([[[12.6651]]], grad_fn=<AddBackward0>)
# tensor([[[12.3762]]], grad_fn=<AddBackward0>)
# tensor([[[13.4931]]], grad_fn=<AddBackward0>)
# tensor([[[14.9093]]], grad_fn=<AddBackward0>)
# tensor([[[14.4420]]], grad_fn=<AddBackward0>)
# tensor([[[15.5900]]], grad_fn=<AddBackward0>)
# tensor([[[16.5223]]], grad_fn=<AddBackward0>)
# tensor([[[15.5216]]], grad_fn=<AddBackward0>)
# tensor([[[15.2321]]], grad_fn=<AddBackward0>)
# tensor([[[15.5471]]], grad_fn=<AddBackward0>)
# tensor([[[17.6679]]], grad_fn=<AddBackward0>)
# tensor([[[14.6246]]], grad_fn=<AddBackward0>)
# tensor([[[15.4776]]], grad_fn=<AddBackward0>)
# tensor([[[15.2690]]], grad_fn=<AddBackward0>)
# tensor([[[13.6624]]], grad_fn=<AddBackward0>)
# tensor([[[13.2174]]], grad_fn=<AddBackward0>)
# tensor([[[14.1415]]], grad_fn=<AddBackward0>)
# tensor([[[12.6558]]], grad_fn=<AddBackward0>)
# tensor([[[12.3701]]], grad_fn=<AddBackward0>)
# tensor([[[11.4819]]], grad_fn=<AddBackward0>)
# tensor([[[12.1099]]], grad_fn=<AddBackward0>)
# tensor([[[11.7482]]], grad_fn=<AddBackward0>)
# tensor([[[13.0844]]], grad_fn=<AddBackward0>)
# tensor([[[11.3735]]], grad_fn=<AddBackward0>)
# tensor([[[11.9463]]], grad_fn=<AddBackward0>)
# tensor([[[11.7325]]], grad_fn=<AddBackward0>)
# tensor([[[10.7721]]], grad_fn=<AddBackward0>)
# tensor([[[12.5118]]], grad_fn=<AddBackward0>)
# tensor([[[10.5619]]], grad_fn=<AddBackward0>)
# tensor([[[12.0458]]], grad_fn=<AddBackward0>)
# tensor([[[10.4127]]], grad_fn=<AddBackward0>)
# tensor([[[10.7615]]], grad_fn=<AddBackward0>)
# tensor([[[10.8257]]], grad_fn=<AddBackward0>)
# tensor([[[11.2547]]], grad_fn=<AddBackward0>)
# tensor([[[10.1257]]], grad_fn=<AddBackward0>)
# tensor([[[11.0833]]], grad_fn=<AddBackward0>)
# tensor([[[9.9713]]], grad_fn=<AddBackward0>)
# tensor([[[10.6210]]], grad_fn=<AddBackward0>)
# tensor([[[10.7350]]], grad_fn=<AddBackward0>)
# tensor([[[10.5293]]], grad_fn=<AddBackward0>)
# tensor([[[12.5316]]], grad_fn=<AddBackward0>)
# tensor([[[11.1093]]], grad_fn=<AddBackward0>)
# tensor([[[12.2285]]], grad_fn=<AddBackward0>)
# tensor([[[12.3980]]], grad_fn=<AddBackward0>)
# tensor([[[13.6783]]], grad_fn=<AddBackward0>)
# tensor([[[13.8600]]], grad_fn=<AddBackward0>)
# tensor([[[11.9906]]], grad_fn=<AddBackward0>)
# tensor([[[12.4363]]], grad_fn=<AddBackward0>)
# tensor([[[11.4618]]], grad_fn=<AddBackward0>)
# tensor([[[11.5715]]], grad_fn=<AddBackward0>)
# tensor([[[11.8162]]], grad_fn=<AddBackward0>)
# tensor([[[11.7985]]], grad_fn=<AddBackward0>)
# tensor([[[12.6544]]], grad_fn=<AddBackward0>)
# tensor([[[13.9115]]], grad_fn=<AddBackward0>)
# tensor([[[12.8843]]], grad_fn=<AddBackward0>)
# tensor([[[12.3443]]], grad_fn=<AddBackward0>)
# tensor([[[13.6666]]], grad_fn=<AddBackward0>)
# tensor([[[12.1979]]], grad_fn=<AddBackward0>)
# tensor([[[12.5074]]], grad_fn=<AddBackward0>)
# tensor([[[12.2743]]], grad_fn=<AddBackward0>)
# tensor([[[12.5894]]], grad_fn=<AddBackward0>)
# tensor([[[12.0208]]], grad_fn=<AddBackward0>)
# tensor([[[12.6630]]], grad_fn=<AddBackward0>)
# tensor([[[13.3743]]], grad_fn=<AddBackward0>)
# tensor([[[13.4065]]], grad_fn=<AddBackward0>)
# tensor([[[13.1681]]], grad_fn=<AddBackward0>)
# tensor([[[14.5942]]], grad_fn=<AddBackward0>)
# tensor([[[12.3034]]], grad_fn=<AddBackward0>)
# tensor([[[13.5146]]], grad_fn=<AddBackward0>)
# tensor([[[14.4200]]], grad_fn=<AddBackward0>)
# tensor([[[14.9503]]], grad_fn=<AddBackward0>)
# tensor([[[13.8883]]], grad_fn=<AddBackward0>)
# tensor([[[12.6145]]], grad_fn=<AddBackward0>)
# tensor([[[12.6490]]], grad_fn=<AddBackward0>)
# tensor([[[13.0610]]], grad_fn=<AddBackward0>)
# tensor([[[12.0331]]], grad_fn=<AddBackward0>)
# tensor([[[13.1516]]], grad_fn=<AddBackward0>)
# tensor([[[15.0059]]], grad_fn=<AddBackward0>)
# tensor([[[14.8792]]], grad_fn=<AddBackward0>)
# tensor([[[14.4800]]], grad_fn=<AddBackward0>)
# tensor([[[14.2148]]], grad_fn=<AddBackward0>)
# tensor([[[14.9522]]], grad_fn=<AddBackward0>)
# tensor([[[15.9911]]], grad_fn=<AddBackward0>)
# tensor([[[14.4440]]], grad_fn=<AddBackward0>)
# tensor([[[14.1357]]], grad_fn=<AddBackward0>)
# tensor([[[15.0590]]], grad_fn=<AddBackward0>)
# tensor([[[15.1877]]], grad_fn=<AddBackward0>)
# tensor([[[14.0166]]], grad_fn=<AddBackward0>)
# tensor([[[12.9158]]], grad_fn=<AddBackward0>)
# tensor([[[12.4616]]], grad_fn=<AddBackward0>)
# tensor([[[12.1732]]], grad_fn=<AddBackward0>)
# tensor([[[10.8951]]], grad_fn=<AddBackward0>)
# tensor([[[9.4993]]], grad_fn=<AddBackward0>)
# tensor([[[9.9301]]], grad_fn=<AddBackward0>)
# tensor([[[8.6744]]], grad_fn=<AddBackward0>)
# tensor([[[9.3740]]], grad_fn=<AddBackward0>)
# tensor([[[9.0748]]], grad_fn=<AddBackward0>)
# tensor([[[8.7124]]], grad_fn=<AddBackward0>)
# tensor([[[8.5880]]], grad_fn=<AddBackward0>)
# tensor([[[9.4886]]], grad_fn=<AddBackward0>)
# tensor([[[9.7567]]], grad_fn=<AddBackward0>)
# tensor([[[10.8403]]], grad_fn=<AddBackward0>)
# tensor([[[9.3225]]], grad_fn=<AddBackward0>)
# tensor([[[10.7824]]], grad_fn=<AddBackward0>)
# tensor([[[10.5910]]], grad_fn=<AddBackward0>)
# tensor([[[11.7531]]], grad_fn=<AddBackward0>)
# tensor([[[12.7743]]], grad_fn=<AddBackward0>)
# tensor([[[12.1627]]], grad_fn=<AddBackward0>)
# tensor([[[13.1403]]], grad_fn=<AddBackward0>)
# tensor([[[12.8441]]], grad_fn=<AddBackward0>)
# tensor([[[14.8292]]], grad_fn=<AddBackward0>)
# tensor([[[13.1281]]], grad_fn=<AddBackward0>)
# tensor([[[13.3212]]], grad_fn=<AddBackward0>)
# tensor([[[14.3996]]], grad_fn=<AddBackward0>)
# tensor([[[14.1435]]], grad_fn=<AddBackward0>)
# tensor([[[14.2115]]], grad_fn=<AddBackward0>)
# tensor([[[14.4361]]], grad_fn=<AddBackward0>)
# tensor([[[13.9399]]], grad_fn=<AddBackward0>)
# tensor([[[12.7423]]], grad_fn=<AddBackward0>)
# tensor([[[13.8445]]], grad_fn=<AddBackward0>)
# tensor([[[12.3538]]], grad_fn=<AddBackward0>)
# tensor([[[13.9790]]], grad_fn=<AddBackward0>)
# tensor([[[12.8484]]], grad_fn=<AddBackward0>)
# tensor([[[12.0767]]], grad_fn=<AddBackward0>)
# tensor([[[12.5061]]], grad_fn=<AddBackward0>)
# tensor([[[13.3143]]], grad_fn=<AddBackward0>)
# tensor([[[12.1337]]], grad_fn=<AddBackward0>)
# tensor([[[13.2023]]], grad_fn=<AddBackward0>)
# tensor([[[11.0603]]], grad_fn=<AddBackward0>)
# tensor([[[12.9885]]], grad_fn=<AddBackward0>)
# tensor([[[12.0251]]], grad_fn=<AddBackward0>)
# tensor([[[11.2958]]], grad_fn=<AddBackward0>)
# tensor([[[12.0399]]], grad_fn=<AddBackward0>)
# tensor([[[11.8309]]], grad_fn=<AddBackward0>)
# tensor([[[11.8282]]], grad_fn=<AddBackward0>)
# tensor([[[12.5129]]], grad_fn=<AddBackward0>)
# tensor([[[13.1133]]], grad_fn=<AddBackward0>)
# tensor([[[12.7632]]], grad_fn=<AddBackward0>)
# tensor([[[15.0202]]], grad_fn=<AddBackward0>)
# tensor([[[13.1264]]], grad_fn=<AddBackward0>)
# tensor([[[14.5021]]], grad_fn=<AddBackward0>)
# tensor([[[15.6234]]], grad_fn=<AddBackward0>)
# tensor([[[13.8564]]], grad_fn=<AddBackward0>)
# tensor([[[14.5747]]], grad_fn=<AddBackward0>)
# tensor([[[13.8662]]], grad_fn=<AddBackward0>)
# tensor([[[13.8759]]], grad_fn=<AddBackward0>)
# tensor([[[12.4649]]], grad_fn=<AddBackward0>)
# tensor([[[13.1343]]], grad_fn=<AddBackward0>)
# tensor([[[12.9040]]], grad_fn=<AddBackward0>)
# tensor([[[12.0752]]], grad_fn=<AddBackward0>)
# tensor([[[10.5255]]], grad_fn=<AddBackward0>)
# tensor([[[10.8438]]], grad_fn=<AddBackward0>)
# tensor([[[10.5726]]], grad_fn=<AddBackward0>)
# tensor([[[10.4369]]], grad_fn=<AddBackward0>)
# tensor([[[10.0545]]], grad_fn=<AddBackward0>)
# tensor([[[10.5418]]], grad_fn=<AddBackward0>)
# tensor([[[9.4522]]], grad_fn=<AddBackward0>)
# tensor([[[9.5553]]], grad_fn=<AddBackward0>)
# tensor([[[9.4391]]], grad_fn=<AddBackward0>)
# tensor([[[9.0097]]], grad_fn=<AddBackward0>)
# tensor([[[8.6582]]], grad_fn=<AddBackward0>)
# tensor([[[9.3882]]], grad_fn=<AddBackward0>)
# tensor([[[8.6378]]], grad_fn=<AddBackward0>)
# tensor([[[8.6933]]], grad_fn=<AddBackward0>)
# tensor([[[8.5567]]], grad_fn=<AddBackward0>)
# tensor([[[9.0314]]], grad_fn=<AddBackward0>)
# tensor([[[9.2626]]], grad_fn=<AddBackward0>)
# tensor([[[9.2172]]], grad_fn=<AddBackward0>)
# tensor([[[10.3670]]], grad_fn=<AddBackward0>)
# tensor([[[9.6978]]], grad_fn=<AddBackward0>)
# tensor([[[10.9620]]], grad_fn=<AddBackward0>)
# tensor([[[11.0862]]], grad_fn=<AddBackward0>)
# tensor([[[10.9653]]], grad_fn=<AddBackward0>)
# tensor([[[12.0540]]], grad_fn=<AddBackward0>)
# tensor([[[13.7179]]], grad_fn=<AddBackward0>)
# tensor([[[13.5353]]], grad_fn=<AddBackward0>)
# tensor([[[13.1251]]], grad_fn=<AddBackward0>)
# tensor([[[14.8603]]], grad_fn=<AddBackward0>)
# tensor([[[14.2535]]], grad_fn=<AddBackward0>)
# tensor([[[14.6948]]], grad_fn=<AddBackward0>)
# tensor([[[15.4284]]], grad_fn=<AddBackward0>)
# tensor([[[15.4324]]], grad_fn=<AddBackward0>)
# tensor([[[15.7951]]], grad_fn=<AddBackward0>)
# tensor([[[14.8721]]], grad_fn=<AddBackward0>)
# tensor([[[14.9972]]], grad_fn=<AddBackward0>)
# tensor([[[17.0341]]], grad_fn=<AddBackward0>)
# tensor([[[15.0337]]], grad_fn=<AddBackward0>)
# tensor([[[14.6723]]], grad_fn=<AddBackward0>)
# tensor([[[13.5699]]], grad_fn=<AddBackward0>)
# tensor([[[13.8008]]], grad_fn=<AddBackward0>)
# tensor([[[11.6197]]], grad_fn=<AddBackward0>)
# tensor([[[11.3250]]], grad_fn=<AddBackward0>)
# tensor([[[11.3514]]], grad_fn=<AddBackward0>)
# tensor([[[10.2615]]], grad_fn=<AddBackward0>)
# tensor([[[11.3359]]], grad_fn=<AddBackward0>)
# tensor([[[10.5884]]], grad_fn=<AddBackward0>)
# tensor([[[10.5767]]], grad_fn=<AddBackward0>)
# tensor([[[12.6458]]], grad_fn=<AddBackward0>)
# tensor([[[11.6588]]], grad_fn=<AddBackward0>)
# tensor([[[12.1446]]], grad_fn=<AddBackward0>)
# tensor([[[14.9087]]], grad_fn=<AddBackward0>)
# tensor([[[15.3528]]], grad_fn=<AddBackward0>)
# tensor([[[13.7713]]], grad_fn=<AddBackward0>)
# tensor([[[16.4584]]], grad_fn=<AddBackward0>)
# tensor([[[18.2436]]], grad_fn=<AddBackward0>)
# tensor([[[16.3563]]], grad_fn=<AddBackward0>)
# tensor([[[17.3580]]], grad_fn=<AddBackward0>)
# tensor([[[16.9557]]], grad_fn=<AddBackward0>)
# tensor([[[16.8654]]], grad_fn=<AddBackward0>)
# tensor([[[17.0092]]], grad_fn=<AddBackward0>)
# tensor([[[16.6245]]], grad_fn=<AddBackward0>)
# tensor([[[19.1818]]], grad_fn=<AddBackward0>)
# tensor([[[16.2973]]], grad_fn=<AddBackward0>)
# tensor([[[18.5811]]], grad_fn=<AddBackward0>)
# tensor([[[17.1294]]], grad_fn=<AddBackward0>)
# tensor([[[17.3636]]], grad_fn=<AddBackward0>)
# tensor([[[16.9667]]], grad_fn=<AddBackward0>)
# tensor([[[17.4067]]], grad_fn=<AddBackward0>)
# tensor([[[17.5463]]], grad_fn=<AddBackward0>)
# tensor([[[17.8663]]], grad_fn=<AddBackward0>)
# tensor([[[17.6440]]], grad_fn=<AddBackward0>)
# tensor([[[18.2455]]], grad_fn=<AddBackward0>)
# tensor([[[16.7757]]], grad_fn=<AddBackward0>)
# tensor([[[16.7410]]], grad_fn=<AddBackward0>)
# tensor([[[15.8112]]], grad_fn=<AddBackward0>)
# tensor([[[16.2476]]], grad_fn=<AddBackward0>)
# tensor([[[15.5386]]], grad_fn=<AddBackward0>)
# tensor([[[16.6323]]], grad_fn=<AddBackward0>)
# tensor([[[13.6591]]], grad_fn=<AddBackward0>)
# tensor([[[13.4390]]], grad_fn=<AddBackward0>)
# tensor([[[12.4354]]], grad_fn=<AddBackward0>)
# tensor([[[13.0797]]], grad_fn=<AddBackward0>)
# tensor([[[12.3295]]], grad_fn=<AddBackward0>)
# tensor([[[9.1065]]], grad_fn=<AddBackward0>)
# tensor([[[11.0358]]], grad_fn=<AddBackward0>)
# tensor([[[9.6400]]], grad_fn=<AddBackward0>)
# tensor([[[10.9126]]], grad_fn=<AddBackward0>)
# tensor([[[9.6458]]], grad_fn=<AddBackward0>)
# tensor([[[10.1292]]], grad_fn=<AddBackward0>)
# tensor([[[10.2807]]], grad_fn=<AddBackward0>)
# tensor([[[10.6548]]], grad_fn=<AddBackward0>)
# tensor([[[11.2876]]], grad_fn=<AddBackward0>)
# tensor([[[10.7588]]], grad_fn=<AddBackward0>)
# tensor([[[11.2910]]], grad_fn=<AddBackward0>)
# tensor([[[11.2466]]], grad_fn=<AddBackward0>)
# tensor([[[11.3720]]], grad_fn=<AddBackward0>)
# tensor([[[12.0682]]], grad_fn=<AddBackward0>)
# tensor([[[11.7946]]], grad_fn=<AddBackward0>)
# tensor([[[10.5353]]], grad_fn=<AddBackward0>)
# tensor([[[10.9777]]], grad_fn=<AddBackward0>)
# tensor([[[11.3783]]], grad_fn=<AddBackward0>)
# tensor([[[9.6053]]], grad_fn=<AddBackward0>)
# tensor([[[8.9540]]], grad_fn=<AddBackward0>)
# tensor([[[10.1397]]], grad_fn=<AddBackward0>)
# tensor([[[10.1687]]], grad_fn=<AddBackward0>)
# tensor([[[9.7970]]], grad_fn=<AddBackward0>)
# tensor([[[9.1389]]], grad_fn=<AddBackward0>)
# tensor([[[9.9446]]], grad_fn=<AddBackward0>)
# tensor([[[9.3535]]], grad_fn=<AddBackward0>)
# tensor([[[9.2086]]], grad_fn=<AddBackward0>)
# tensor([[[10.1406]]], grad_fn=<AddBackward0>)
# tensor([[[10.3063]]], grad_fn=<AddBackward0>)
# tensor([[[9.4371]]], grad_fn=<AddBackward0>)
# tensor([[[8.9851]]], grad_fn=<AddBackward0>)
# tensor([[[9.6527]]], grad_fn=<AddBackward0>)
# tensor([[[9.3216]]], grad_fn=<AddBackward0>)
# tensor([[[8.9380]]], grad_fn=<AddBackward0>)
# tensor([[[9.0781]]], grad_fn=<AddBackward0>)
# tensor([[[8.3374]]], grad_fn=<AddBackward0>)
# tensor([[[8.3578]]], grad_fn=<AddBackward0>)
# tensor([[[7.8030]]], grad_fn=<AddBackward0>)
# tensor([[[7.2092]]], grad_fn=<AddBackward0>)
# tensor([[[6.9193]]], grad_fn=<AddBackward0>)
# tensor([[[6.7625]]], grad_fn=<AddBackward0>)
# tensor([[[7.4093]]], grad_fn=<AddBackward0>)
# tensor([[[6.8861]]], grad_fn=<AddBackward0>)
# tensor([[[6.6875]]], grad_fn=<AddBackward0>)
# tensor([[[6.7320]]], grad_fn=<AddBackward0>)
# tensor([[[6.5950]]], grad_fn=<AddBackward0>)
# tensor([[[6.7557]]], grad_fn=<AddBackward0>)
# tensor([[[6.6219]]], grad_fn=<AddBackward0>)
# tensor([[[6.6867]]], grad_fn=<AddBackward0>)
# tensor([[[6.3333]]], grad_fn=<AddBackward0>)
# tensor([[[6.0740]]], grad_fn=<AddBackward0>)
# tensor([[[5.8756]]], grad_fn=<AddBackward0>)
# tensor([[[6.1027]]], grad_fn=<AddBackward0>)
# tensor([[[5.9886]]], grad_fn=<AddBackward0>)
# tensor([[[5.7910]]], grad_fn=<AddBackward0>)
# tensor([[[5.8757]]], grad_fn=<AddBackward0>)
# tensor([[[5.7445]]], grad_fn=<AddBackward0>)
# tensor([[[6.0937]]], grad_fn=<AddBackward0>)
# tensor([[[6.1803]]], grad_fn=<AddBackward0>)
# tensor([[[6.1891]]], grad_fn=<AddBackward0>)
# tensor([[[6.6615]]], grad_fn=<AddBackward0>)
# tensor([[[7.1383]]], grad_fn=<AddBackward0>)
# tensor([[[6.4618]]], grad_fn=<AddBackward0>)
# tensor([[[6.7259]]], grad_fn=<AddBackward0>)
# tensor([[[7.5644]]], grad_fn=<AddBackward0>)
# tensor([[[7.1086]]], grad_fn=<AddBackward0>)
# tensor([[[7.7277]]], grad_fn=<AddBackward0>)
# tensor([[[8.1505]]], grad_fn=<AddBackward0>)
# tensor([[[8.2817]]], grad_fn=<AddBackward0>)
# tensor([[[8.5258]]], grad_fn=<AddBackward0>)
# tensor([[[8.2912]]], grad_fn=<AddBackward0>)
# tensor([[[9.0605]]], grad_fn=<AddBackward0>)
# tensor([[[9.6911]]], grad_fn=<AddBackward0>)
# tensor([[[8.7019]]], grad_fn=<AddBackward0>)
# tensor([[[9.3513]]], grad_fn=<AddBackward0>)
# tensor([[[9.5681]]], grad_fn=<AddBackward0>)
# tensor([[[10.8148]]], grad_fn=<AddBackward0>)
# tensor([[[9.3925]]], grad_fn=<AddBackward0>)
# tensor([[[9.1737]]], grad_fn=<AddBackward0>)
# tensor([[[9.9190]]], grad_fn=<AddBackward0>)
# tensor([[[9.0697]]], grad_fn=<AddBackward0>)
# tensor([[[9.4966]]], grad_fn=<AddBackward0>)
# tensor([[[8.8880]]], grad_fn=<AddBackward0>)
# tensor([[[9.6986]]], grad_fn=<AddBackward0>)
# tensor([[[8.1546]]], grad_fn=<AddBackward0>)
# tensor([[[8.2459]]], grad_fn=<AddBackward0>)
# tensor([[[8.1617]]], grad_fn=<AddBackward0>)
# tensor([[[8.2786]]], grad_fn=<AddBackward0>)
# tensor([[[8.4884]]], grad_fn=<AddBackward0>)
# tensor([[[8.6954]]], grad_fn=<AddBackward0>)
# tensor([[[8.0242]]], grad_fn=<AddBackward0>)
# tensor([[[8.4642]]], grad_fn=<AddBackward0>)
# tensor([[[8.4331]]], grad_fn=<AddBackward0>)
# tensor([[[8.0412]]], grad_fn=<AddBackward0>)
# tensor([[[8.4658]]], grad_fn=<AddBackward0>)
# tensor([[[8.5543]]], grad_fn=<AddBackward0>)
# tensor([[[8.8915]]], grad_fn=<AddBackward0>)
# tensor([[[9.1533]]], grad_fn=<AddBackward0>)
# tensor([[[8.0321]]], grad_fn=<AddBackward0>)
# tensor([[[8.9260]]], grad_fn=<AddBackward0>)
# tensor([[[9.2509]]], grad_fn=<AddBackward0>)
# tensor([[[10.1224]]], grad_fn=<AddBackward0>)
# tensor([[[9.0595]]], grad_fn=<AddBackward0>)
# tensor([[[10.0918]]], grad_fn=<AddBackward0>)
# tensor([[[9.6835]]], grad_fn=<AddBackward0>)
# tensor([[[9.2527]]], grad_fn=<AddBackward0>)
# tensor([[[10.0347]]], grad_fn=<AddBackward0>)
# tensor([[[9.4498]]], grad_fn=<AddBackward0>)
# tensor([[[9.7616]]], grad_fn=<AddBackward0>)
# tensor([[[9.3847]]], grad_fn=<AddBackward0>)
# tensor([[[11.1490]]], grad_fn=<AddBackward0>)
# tensor([[[9.8254]]], grad_fn=<AddBackward0>)
# tensor([[[10.1110]]], grad_fn=<AddBackward0>)
# tensor([[[10.3182]]], grad_fn=<AddBackward0>)
# tensor([[[11.5083]]], grad_fn=<AddBackward0>)
# tensor([[[9.9264]]], grad_fn=<AddBackward0>)
# tensor([[[9.6868]]], grad_fn=<AddBackward0>)
# tensor([[[9.9435]]], grad_fn=<AddBackward0>)
# tensor([[[9.7203]]], grad_fn=<AddBackward0>)
# tensor([[[8.9750]]], grad_fn=<AddBackward0>)
# tensor([[[8.7976]]], grad_fn=<AddBackward0>)
# tensor([[[9.2237]]], grad_fn=<AddBackward0>)
# tensor([[[7.6496]]], grad_fn=<AddBackward0>)
# tensor([[[8.1072]]], grad_fn=<AddBackward0>)
# tensor([[[7.2674]]], grad_fn=<AddBackward0>)
# tensor([[[6.7136]]], grad_fn=<AddBackward0>)
# tensor([[[6.6566]]], grad_fn=<AddBackward0>)
# tensor([[[6.6704]]], grad_fn=<AddBackward0>)
# tensor([[[6.3711]]], grad_fn=<AddBackward0>)
# tensor([[[6.9405]]], grad_fn=<AddBackward0>)
# tensor([[[7.3806]]], grad_fn=<AddBackward0>)
# tensor([[[7.4444]]], grad_fn=<AddBackward0>)
# tensor([[[7.0831]]], grad_fn=<AddBackward0>)
# tensor([[[6.5341]]], grad_fn=<AddBackward0>)
# tensor([[[5.8743]]], grad_fn=<AddBackward0>)
# tensor([[[6.6053]]], grad_fn=<AddBackward0>)
# tensor([[[6.2737]]], grad_fn=<AddBackward0>)
# tensor([[[6.2186]]], grad_fn=<AddBackward0>)
# tensor([[[5.9880]]], grad_fn=<AddBackward0>)
# tensor([[[6.4471]]], grad_fn=<AddBackward0>)
# tensor([[[6.3096]]], grad_fn=<AddBackward0>)
# tensor([[[7.1147]]], grad_fn=<AddBackward0>)
# tensor([[[6.7592]]], grad_fn=<AddBackward0>)
# tensor([[[6.4304]]], grad_fn=<AddBackward0>)
# tensor([[[6.8480]]], grad_fn=<AddBackward0>)
# tensor([[[6.3473]]], grad_fn=<AddBackward0>)
# tensor([[[7.3282]]], grad_fn=<AddBackward0>)
# tensor([[[6.6572]]], grad_fn=<AddBackward0>)
# tensor([[[6.9308]]], grad_fn=<AddBackward0>)
# tensor([[[6.9734]]], grad_fn=<AddBackward0>)
# tensor([[[7.1509]]], grad_fn=<AddBackward0>)
# tensor([[[6.9749]]], grad_fn=<AddBackward0>)
# tensor([[[7.4312]]], grad_fn=<AddBackward0>)
# tensor([[[8.0939]]], grad_fn=<AddBackward0>)
# tensor([[[7.7314]]], grad_fn=<AddBackward0>)
# tensor([[[8.4920]]], grad_fn=<AddBackward0>)
# tensor([[[8.5787]]], grad_fn=<AddBackward0>)
# tensor([[[9.7303]]], grad_fn=<AddBackward0>)
# tensor([[[9.8895]]], grad_fn=<AddBackward0>)
# tensor([[[10.0803]]], grad_fn=<AddBackward0>)
# tensor([[[9.6660]]], grad_fn=<AddBackward0>)
# tensor([[[9.9883]]], grad_fn=<AddBackward0>)
# tensor([[[9.8422]]], grad_fn=<AddBackward0>)
# tensor([[[9.4240]]], grad_fn=<AddBackward0>)
# tensor([[[8.7821]]], grad_fn=<AddBackward0>)
# tensor([[[9.5995]]], grad_fn=<AddBackward0>)
# tensor([[[9.3939]]], grad_fn=<AddBackward0>)
# tensor([[[8.5023]]], grad_fn=<AddBackward0>)
# tensor([[[7.8838]]], grad_fn=<AddBackward0>)
# tensor([[[7.1297]]], grad_fn=<AddBackward0>)
# tensor([[[6.9800]]], grad_fn=<AddBackward0>)
# tensor([[[6.2587]]], grad_fn=<AddBackward0>)
# tensor([[[6.6357]]], grad_fn=<AddBackward0>)
# tensor([[[6.5732]]], grad_fn=<AddBackward0>)
# tensor([[[6.5821]]], grad_fn=<AddBackward0>)
# tensor([[[7.9029]]], grad_fn=<AddBackward0>)
# tensor([[[8.1525]]], grad_fn=<AddBackward0>)
# tensor([[[7.2011]]], grad_fn=<AddBackward0>)
# tensor([[[7.1764]]], grad_fn=<AddBackward0>)
# tensor([[[8.5340]]], grad_fn=<AddBackward0>)
# tensor([[[7.7986]]], grad_fn=<AddBackward0>)
# tensor([[[8.1307]]], grad_fn=<AddBackward0>)
# tensor([[[9.5325]]], grad_fn=<AddBackward0>)
# tensor([[[9.3974]]], grad_fn=<AddBackward0>)
# tensor([[[9.0046]]], grad_fn=<AddBackward0>)
# tensor([[[9.9339]]], grad_fn=<AddBackward0>)
# tensor([[[9.1723]]], grad_fn=<AddBackward0>)
# tensor([[[10.7447]]], grad_fn=<AddBackward0>)
# tensor([[[10.6509]]], grad_fn=<AddBackward0>)
# tensor([[[11.5548]]], grad_fn=<AddBackward0>)
# tensor([[[11.3715]]], grad_fn=<AddBackward0>)
# tensor([[[11.6288]]], grad_fn=<AddBackward0>)
# tensor([[[11.8171]]], grad_fn=<AddBackward0>)
# tensor([[[10.3128]]], grad_fn=<AddBackward0>)
# tensor([[[10.4234]]], grad_fn=<AddBackward0>)
# tensor([[[8.7946]]], grad_fn=<AddBackward0>)
# tensor([[[8.5755]]], grad_fn=<AddBackward0>)
# tensor([[[8.4970]]], grad_fn=<AddBackward0>)
# tensor([[[8.2105]]], grad_fn=<AddBackward0>)
# tensor([[[8.0068]]], grad_fn=<AddBackward0>)
# tensor([[[7.9679]]], grad_fn=<AddBackward0>)
# tensor([[[7.7921]]], grad_fn=<AddBackward0>)
# tensor([[[7.7386]]], grad_fn=<AddBackward0>)
# tensor([[[7.7445]]], grad_fn=<AddBackward0>)
# tensor([[[8.2822]]], grad_fn=<AddBackward0>)
# tensor([[[7.0852]]], grad_fn=<AddBackward0>)
# tensor([[[8.1922]]], grad_fn=<AddBackward0>)
# tensor([[[8.5111]]], grad_fn=<AddBackward0>)
# tensor([[[8.5864]]], grad_fn=<AddBackward0>)
# tensor([[[9.1983]]], grad_fn=<AddBackward0>)
# tensor([[[10.1152]]], grad_fn=<AddBackward0>)
# tensor([[[10.4002]]], grad_fn=<AddBackward0>)
# tensor([[[10.9017]]], grad_fn=<AddBackward0>)
# tensor([[[11.5749]]], grad_fn=<AddBackward0>)
# tensor([[[11.4872]]], grad_fn=<AddBackward0>)
# tensor([[[12.3500]]], grad_fn=<AddBackward0>)
# tensor([[[12.3361]]], grad_fn=<AddBackward0>)
# tensor([[[12.0025]]], grad_fn=<AddBackward0>)
# tensor([[[12.2584]]], grad_fn=<AddBackward0>)
# tensor([[[12.1091]]], grad_fn=<AddBackward0>)
# tensor([[[12.9369]]], grad_fn=<AddBackward0>)
# tensor([[[11.2453]]], grad_fn=<AddBackward0>)
# tensor([[[10.7058]]], grad_fn=<AddBackward0>)
# tensor([[[10.7679]]], grad_fn=<AddBackward0>)
# tensor([[[10.8432]]], grad_fn=<AddBackward0>)
# tensor([[[10.0955]]], grad_fn=<AddBackward0>)
# tensor([[[9.4278]]], grad_fn=<AddBackward0>)
# tensor([[[9.2860]]], grad_fn=<AddBackward0>)
# tensor([[[9.2360]]], grad_fn=<AddBackward0>)
# tensor([[[8.4489]]], grad_fn=<AddBackward0>)
# tensor([[[8.7535]]], grad_fn=<AddBackward0>)
# tensor([[[7.7761]]], grad_fn=<AddBackward0>)
# tensor([[[8.1716]]], grad_fn=<AddBackward0>)
# tensor([[[8.3145]]], grad_fn=<AddBackward0>)
# tensor([[[7.7060]]], grad_fn=<AddBackward0>)
# tensor([[[7.5511]]], grad_fn=<AddBackward0>)
# tensor([[[7.1092]]], grad_fn=<AddBackward0>)
# tensor([[[7.1338]]], grad_fn=<AddBackward0>)
# tensor([[[6.8698]]], grad_fn=<AddBackward0>)
# tensor([[[7.4579]]], grad_fn=<AddBackward0>)
# tensor([[[7.4950]]], grad_fn=<AddBackward0>)
# tensor([[[7.5530]]], grad_fn=<AddBackward0>)
# tensor([[[8.2232]]], grad_fn=<AddBackward0>)
# tensor([[[9.1788]]], grad_fn=<AddBackward0>)
# tensor([[[8.4066]]], grad_fn=<AddBackward0>)
# tensor([[[8.6565]]], grad_fn=<AddBackward0>)
# tensor([[[9.0553]]], grad_fn=<AddBackward0>)
# tensor([[[9.0545]]], grad_fn=<AddBackward0>)
# tensor([[[8.6241]]], grad_fn=<AddBackward0>)
# tensor([[[8.5575]]], grad_fn=<AddBackward0>)
# tensor([[[9.3544]]], grad_fn=<AddBackward0>)
# tensor([[[8.6972]]], grad_fn=<AddBackward0>)
# tensor([[[10.1675]]], grad_fn=<AddBackward0>)
# tensor([[[8.8990]]], grad_fn=<AddBackward0>)
# tensor([[[10.1551]]], grad_fn=<AddBackward0>)
# tensor([[[9.5896]]], grad_fn=<AddBackward0>)
# tensor([[[9.6140]]], grad_fn=<AddBackward0>)
# tensor([[[9.9584]]], grad_fn=<AddBackward0>)
# tensor([[[10.0400]]], grad_fn=<AddBackward0>)
# tensor([[[10.0627]]], grad_fn=<AddBackward0>)
# tensor([[[9.7892]]], grad_fn=<AddBackward0>)
# tensor([[[10.2157]]], grad_fn=<AddBackward0>)
# tensor([[[10.1693]]], grad_fn=<AddBackward0>)
# tensor([[[9.9537]]], grad_fn=<AddBackward0>)
# tensor([[[10.2124]]], grad_fn=<AddBackward0>)
# tensor([[[9.6844]]], grad_fn=<AddBackward0>)
# tensor([[[10.0776]]], grad_fn=<AddBackward0>)
# tensor([[[9.2915]]], grad_fn=<AddBackward0>)
# tensor([[[8.9296]]], grad_fn=<AddBackward0>)
# tensor([[[8.5419]]], grad_fn=<AddBackward0>)
# tensor([[[8.1635]]], grad_fn=<AddBackward0>)
# tensor([[[7.4221]]], grad_fn=<AddBackward0>)
# tensor([[[7.5936]]], grad_fn=<AddBackward0>)
# tensor([[[6.8941]]], grad_fn=<AddBackward0>)
# tensor([[[7.3183]]], grad_fn=<AddBackward0>)
# tensor([[[7.0712]]], grad_fn=<AddBackward0>)
# tensor([[[7.2794]]], grad_fn=<AddBackward0>)
# tensor([[[7.6462]]], grad_fn=<AddBackward0>)
# tensor([[[7.6879]]], grad_fn=<AddBackward0>)
# tensor([[[7.9979]]], grad_fn=<AddBackward0>)
# tensor([[[7.8183]]], grad_fn=<AddBackward0>)
# tensor([[[8.2782]]], grad_fn=<AddBackward0>)
# tensor([[[8.8277]]], grad_fn=<AddBackward0>)
# tensor([[[9.2133]]], grad_fn=<AddBackward0>)
# tensor([[[8.8950]]], grad_fn=<AddBackward0>)
# tensor([[[9.4144]]], grad_fn=<AddBackward0>)
# tensor([[[9.2878]]], grad_fn=<AddBackward0>)
# tensor([[[11.7616]]], grad_fn=<AddBackward0>)
# tensor([[[9.4504]]], grad_fn=<AddBackward0>)
# tensor([[[10.2145]]], grad_fn=<AddBackward0>)
# tensor([[[10.6368]]], grad_fn=<AddBackward0>)
# tensor([[[10.2569]]], grad_fn=<AddBackward0>)
# tensor([[[10.1511]]], grad_fn=<AddBackward0>)
# tensor([[[9.8610]]], grad_fn=<AddBackward0>)
# tensor([[[9.3327]]], grad_fn=<AddBackward0>)
# tensor([[[9.3097]]], grad_fn=<AddBackward0>)
# tensor([[[10.1501]]], grad_fn=<AddBackward0>)
# tensor([[[10.1751]]], grad_fn=<AddBackward0>)
# tensor([[[10.2384]]], grad_fn=<AddBackward0>)
# tensor([[[10.0721]]], grad_fn=<AddBackward0>)
# tensor([[[10.5033]]], grad_fn=<AddBackward0>)
# tensor([[[9.3000]]], grad_fn=<AddBackward0>)
# tensor([[[9.5734]]], grad_fn=<AddBackward0>)
# tensor([[[8.8253]]], grad_fn=<AddBackward0>)
# tensor([[[8.4663]]], grad_fn=<AddBackward0>)
# tensor([[[8.2190]]], grad_fn=<AddBackward0>)
# tensor([[[8.4571]]], grad_fn=<AddBackward0>)
# tensor([[[8.3139]]], grad_fn=<AddBackward0>)
# tensor([[[8.6105]]], grad_fn=<AddBackward0>)
# tensor([[[8.2337]]], grad_fn=<AddBackward0>)
# tensor([[[8.3346]]], grad_fn=<AddBackward0>)
# tensor([[[8.4949]]], grad_fn=<AddBackward0>)
# tensor([[[8.5075]]], grad_fn=<AddBackward0>)
# tensor([[[8.5401]]], grad_fn=<AddBackward0>)
# tensor([[[8.0955]]], grad_fn=<AddBackward0>)
# tensor([[[8.3058]]], grad_fn=<AddBackward0>)
# tensor([[[8.1849]]], grad_fn=<AddBackward0>)
# tensor([[[8.7411]]], grad_fn=<AddBackward0>)
# tensor([[[9.7595]]], grad_fn=<AddBackward0>)
# tensor([[[9.4295]]], grad_fn=<AddBackward0>)
# tensor([[[10.0088]]], grad_fn=<AddBackward0>)
# tensor([[[8.9528]]], grad_fn=<AddBackward0>)
# tensor([[[9.7634]]], grad_fn=<AddBackward0>)
# tensor([[[8.7907]]], grad_fn=<AddBackward0>)
# tensor([[[9.8160]]], grad_fn=<AddBackward0>)
# tensor([[[11.0543]]], grad_fn=<AddBackward0>)
# tensor([[[11.0696]]], grad_fn=<AddBackward0>)
# tensor([[[11.0069]]], grad_fn=<AddBackward0>)
# tensor([[[12.5671]]], grad_fn=<AddBackward0>)
# tensor([[[11.7149]]], grad_fn=<AddBackward0>)
# tensor([[[12.2733]]], grad_fn=<AddBackward0>)
# tensor([[[12.4750]]], grad_fn=<AddBackward0>)
# tensor([[[12.0022]]], grad_fn=<AddBackward0>)
# tensor([[[12.1227]]], grad_fn=<AddBackward0>)
# tensor([[[11.5742]]], grad_fn=<AddBackward0>)
# tensor([[[11.7358]]], grad_fn=<AddBackward0>)
# tensor([[[11.3299]]], grad_fn=<AddBackward0>)
# tensor([[[10.4000]]], grad_fn=<AddBackward0>)
# tensor([[[10.4135]]], grad_fn=<AddBackward0>)
# tensor([[[9.4129]]], grad_fn=<AddBackward0>)
# tensor([[[10.1366]]], grad_fn=<AddBackward0>)
# tensor([[[9.2116]]], grad_fn=<AddBackward0>)
# tensor([[[7.9442]]], grad_fn=<AddBackward0>)
# tensor([[[8.0501]]], grad_fn=<AddBackward0>)
# tensor([[[8.1275]]], grad_fn=<AddBackward0>)
# tensor([[[7.9863]]], grad_fn=<AddBackward0>)
# tensor([[[7.3996]]], grad_fn=<AddBackward0>)
# tensor([[[7.5400]]], grad_fn=<AddBackward0>)
# tensor([[[7.3925]]], grad_fn=<AddBackward0>)
# tensor([[[6.8584]]], grad_fn=<AddBackward0>)
# tensor([[[6.8690]]], grad_fn=<AddBackward0>)
# tensor([[[7.9954]]], grad_fn=<AddBackward0>)
# tensor([[[6.5480]]], grad_fn=<AddBackward0>)
# tensor([[[7.0205]]], grad_fn=<AddBackward0>)
# tensor([[[6.7983]]], grad_fn=<AddBackward0>)
# tensor([[[7.5811]]], grad_fn=<AddBackward0>)
# tensor([[[7.3223]]], grad_fn=<AddBackward0>)
# tensor([[[7.8040]]], grad_fn=<AddBackward0>)
# tensor([[[7.8968]]], grad_fn=<AddBackward0>)
# tensor([[[8.4512]]], grad_fn=<AddBackward0>)
# tensor([[[8.3080]]], grad_fn=<AddBackward0>)
# tensor([[[8.0900]]], grad_fn=<AddBackward0>)
# tensor([[[8.3696]]], grad_fn=<AddBackward0>)
# tensor([[[8.0750]]], grad_fn=<AddBackward0>)
# tensor([[[8.4741]]], grad_fn=<AddBackward0>)
# tensor([[[7.8567]]], grad_fn=<AddBackward0>)
# tensor([[[8.1113]]], grad_fn=<AddBackward0>)
# tensor([[[8.5793]]], grad_fn=<AddBackward0>)
# tensor([[[8.6896]]], grad_fn=<AddBackward0>)
# tensor([[[8.7288]]], grad_fn=<AddBackward0>)
# tensor([[[8.6484]]], grad_fn=<AddBackward0>)
# tensor([[[8.3492]]], grad_fn=<AddBackward0>)
# tensor([[[8.6229]]], grad_fn=<AddBackward0>)
# tensor([[[8.0505]]], grad_fn=<AddBackward0>)
# tensor([[[8.6264]]], grad_fn=<AddBackward0>)
# tensor([[[8.2082]]], grad_fn=<AddBackward0>)
# tensor([[[8.6302]]], grad_fn=<AddBackward0>)
# tensor([[[8.1104]]], grad_fn=<AddBackward0>)
# tensor([[[8.3283]]], grad_fn=<AddBackward0>)
# tensor([[[8.7558]]], grad_fn=<AddBackward0>)
# tensor([[[8.3664]]], grad_fn=<AddBackward0>)
# tensor([[[8.9642]]], grad_fn=<AddBackward0>)
# tensor([[[9.4654]]], grad_fn=<AddBackward0>)
# tensor([[[9.7725]]], grad_fn=<AddBackward0>)
# tensor([[[9.6435]]], grad_fn=<AddBackward0>)
# tensor([[[9.7596]]], grad_fn=<AddBackward0>)
# tensor([[[11.0812]]], grad_fn=<AddBackward0>)
# tensor([[[10.1660]]], grad_fn=<AddBackward0>)
# tensor([[[11.0413]]], grad_fn=<AddBackward0>)
# tensor([[[10.3208]]], grad_fn=<AddBackward0>)
# tensor([[[10.4548]]], grad_fn=<AddBackward0>)
# tensor([[[11.1965]]], grad_fn=<AddBackward0>)
# tensor([[[10.3015]]], grad_fn=<AddBackward0>)
# tensor([[[11.4100]]], grad_fn=<AddBackward0>)
# tensor([[[11.4938]]], grad_fn=<AddBackward0>)
# tensor([[[12.2501]]], grad_fn=<AddBackward0>)
# tensor([[[11.4206]]], grad_fn=<AddBackward0>)
# tensor([[[10.3337]]], grad_fn=<AddBackward0>)
# tensor([[[12.2659]]], grad_fn=<AddBackward0>)
# tensor([[[12.8840]]], grad_fn=<AddBackward0>)
# tensor([[[13.2091]]], grad_fn=<AddBackward0>)
# ...
# tensor([[[14.7922]]], grad_fn=<AddBackward0>)
# tensor([[[14.0707]]], grad_fn=<AddBackward0>)
# tensor([[[13.2030]]], grad_fn=<AddBackward0>)
# tensor([[[10.3936]]], grad_fn=<AddBackward0>)
# tensor([[[12.4120]]], grad_fn=<AddBackward0>)
# tensor([[[12.6509]]], grad_fn=<AddBackward0>)
# tensor([[[10.9751]]], grad_fn=<AddBackward0>)
# tensor([[[13.9060]]], grad_fn=<AddBackward0>)
# tensor([[[12.7094]]], grad_fn=<AddBackward0>)
# tensor([[[12.5198]]], grad_fn=<AddBackward0>)
# tensor([[[13.6539]]], grad_fn=<AddBackward0>)
# tensor([[[10.5323]]], grad_fn=<AddBackward0>)
# tensor([[[12.9835]]], grad_fn=<AddBackward0>)
# tensor([[[11.2322]]], grad_fn=<AddBackward0>)
# tensor([[[12.8342]]], grad_fn=<AddBackward0>)
# tensor([[[13.7488]]], grad_fn=<AddBackward0>)
# tensor([[[11.6609]]], grad_fn=<AddBackward0>)
# tensor([[[8.8052]]], grad_fn=<AddBackward0>)
# tensor([[[11.3181]]], grad_fn=<AddBackward0>)
# tensor([[[12.8030]]], grad_fn=<AddBackward0>)
# tensor([[[9.4562]]], grad_fn=<AddBackward0>)
# tensor([[[12.1630]]], grad_fn=<AddBackward0>)
# tensor([[[12.7452]]], grad_fn=<AddBackward0>)
# tensor([[[11.9817]]], grad_fn=<AddBackward0>)
# tensor([[[12.6395]]], grad_fn=<AddBackward0>)
# tensor([[[16.6771]]], grad_fn=<AddBackward0>)
# tensor([[[15.9370]]], grad_fn=<AddBackward0>)
# tensor([[[11.2527]]], grad_fn=<AddBackward0>)
# tensor([[[11.3101]]], grad_fn=<AddBackward0>)
# tensor([[[13.1285]]], grad_fn=<AddBackward0>)
# tensor([[[12.0873]]], grad_fn=<AddBackward0>)
# tensor([[[11.5407]]], grad_fn=<AddBackward0>)
# tensor([[[10.9001]]], grad_fn=<AddBackward0>)
# tensor([[[11.0117]]], grad_fn=<AddBackward0>)
# tensor([[[12.5390]]], grad_fn=<AddBackward0>)
# tensor([[[14.6202]]], grad_fn=<AddBackward0>)
# tensor([[[9.8867]]], grad_fn=<AddBackward0>)
# tensor([[[10.4298]]], grad_fn=<AddBackward0>)
# tensor([[[12.0807]]], grad_fn=<AddBackward0>)
# tensor([[[12.4399]]], grad_fn=<AddBackward0>)
# tensor([[[14.0674]]], grad_fn=<AddBackward0>)
# tensor([[[12.7594]]], grad_fn=<AddBackward0>)
# tensor([[[13.3079]]], grad_fn=<AddBackward0>)
# tensor([[[14.6581]]], grad_fn=<AddBackward0>)
# tensor([[[9.5356]]], grad_fn=<AddBackward0>)
# tensor([[[13.3861]]], grad_fn=<AddBackward0>)
# tensor([[[16.7067]]], grad_fn=<AddBackward0>)
# tensor([[[10.4461]]], grad_fn=<AddBackward0>)
# tensor([[[12.9011]]], grad_fn=<AddBackward0>)
# tensor([[[10.5054]]], grad_fn=<AddBackward0>)
# tensor([[[15.9463]]], grad_fn=<AddBackward0>)
# tensor([[[9.1376]]], grad_fn=<AddBackward0>)
# tensor([[[11.8691]]], grad_fn=<AddBackward0>)
# tensor([[[10.8137]]], grad_fn=<AddBackward0>)
# tensor([[[10.4409]]], grad_fn=<AddBackward0>)
# tensor([[[8.8005]]], grad_fn=<AddBackward0>)
# tensor([[[11.5201]]], grad_fn=<AddBackward0>)
# tensor([[[11.9034]]], grad_fn=<AddBackward0>)
# tensor([[[10.0385]]], grad_fn=<AddBackward0>)
# tensor([[[14.0473]]], grad_fn=<AddBackward0>)
# tensor([[[11.4340]]], grad_fn=<AddBackward0>)
# tensor([[[10.4077]]], grad_fn=<AddBackward0>)
# tensor([[[12.9887]]], grad_fn=<AddBackward0>)
# tensor([[[12.4304]]], grad_fn=<AddBackward0>)
# tensor([[[12.3453]]], grad_fn=<AddBackward0>)
# tensor([[[12.7840]]], grad_fn=<AddBackward0>)
# tensor([[[12.6838]]], grad_fn=<AddBackward0>)
# tensor([[[7.8454]]], grad_fn=<AddBackward0>)
# tensor([[[12.7672]]], grad_fn=<AddBackward0>)
# tensor([[[10.1895]]], grad_fn=<AddBackward0>)
# tensor([[[7.9446]]], grad_fn=<AddBackward0>)
# tensor([[[10.7382]]], grad_fn=<AddBackward0>)
# tensor([[[10.4687]]], grad_fn=<AddBackward0>)
# tensor([[[9.8480]]], grad_fn=<AddBackward0>)
# tensor([[[12.8488]]], grad_fn=<AddBackward0>)
# tensor([[[10.9490]]], grad_fn=<AddBackward0>)
# tensor([[[11.4532]]], grad_fn=<AddBackward0>)
# tensor([[[14.6368]]], grad_fn=<AddBackward0>)
# tensor([[[11.0670]]], grad_fn=<AddBackward0>)
# tensor([[[13.7148]]], grad_fn=<AddBackward0>)
# tensor([[[13.3734]]], grad_fn=<AddBackward0>)
# tensor([[[11.8693]]], grad_fn=<AddBackward0>)
# tensor([[[10.6356]]], grad_fn=<AddBackward0>)
# tensor([[[14.1799]]], grad_fn=<AddBackward0>)
# tensor([[[14.7928]]], grad_fn=<AddBackward0>)
# tensor([[[14.6039]]], grad_fn=<AddBackward0>)
# tensor([[[15.5729]]], grad_fn=<AddBackward0>)
# tensor([[[16.0565]]], grad_fn=<AddBackward0>)
# tensor([[[11.0101]]], grad_fn=<AddBackward0>)
# tensor([[[11.8470]]], grad_fn=<AddBackward0>)
# tensor([[[14.2603]]], grad_fn=<AddBackward0>)
# tensor([[[14.4122]]], grad_fn=<AddBackward0>)
# tensor([[[13.9586]]], grad_fn=<AddBackward0>)
# tensor([[[9.0284]]], grad_fn=<AddBackward0>)
# tensor([[[15.1201]]], grad_fn=<AddBackward0>)
# tensor([[[12.0861]]], grad_fn=<AddBackward0>)
# tensor([[[11.5361]]], grad_fn=<AddBackward0>)
# tensor([[[15.8257]]], grad_fn=<AddBackward0>)
# tensor([[[13.7362]]], grad_fn=<AddBackward0>)
# tensor([[[15.6364]]], grad_fn=<AddBackward0>)
# tensor([[[13.7747]]], grad_fn=<AddBackward0>)
# tensor([[[12.9712]]], grad_fn=<AddBackward0>)
# tensor([[[9.2245]]], grad_fn=<AddBackward0>)
# tensor([[[12.6479]]], grad_fn=<AddBackward0>)
# tensor([[[12.3544]]], grad_fn=<AddBackward0>)
# tensor([[[10.2971]]], grad_fn=<AddBackward0>)
# tensor([[[14.6298]]], grad_fn=<AddBackward0>)
# tensor([[[12.3152]]], grad_fn=<AddBackward0>)
# tensor([[[12.9806]]], grad_fn=<AddBackward0>)
# tensor([[[13.6169]]], grad_fn=<AddBackward0>)
# tensor([[[14.2648]]], grad_fn=<AddBackward0>)
# tensor([[[14.5317]]], grad_fn=<AddBackward0>)
# tensor([[[14.1444]]], grad_fn=<AddBackward0>)
# tensor([[[14.7310]]], grad_fn=<AddBackward0>)
# tensor([[[9.5730]]], grad_fn=<AddBackward0>)
# tensor([[[15.6383]]], grad_fn=<AddBackward0>)
# tensor([[[11.6152]]], grad_fn=<AddBackward0>)
# tensor([[[7.8760]]], grad_fn=<AddBackward0>)
# tensor([[[14.2773]]], grad_fn=<AddBackward0>)
# tensor([[[7.9122]]], grad_fn=<AddBackward0>)
# tensor([[[12.1530]]], grad_fn=<AddBackward0>)
# tensor([[[12.3412]]], grad_fn=<AddBackward0>)
# tensor([[[14.7703]]], grad_fn=<AddBackward0>)
# tensor([[[11.9396]]], grad_fn=<AddBackward0>)
# tensor([[[12.7799]]], grad_fn=<AddBackward0>)
# tensor([[[13.3456]]], grad_fn=<AddBackward0>)
# tensor([[[13.5357]]], grad_fn=<AddBackward0>)
# tensor([[[17.8961]]], grad_fn=<AddBackward0>)
# tensor([[[13.8986]]], grad_fn=<AddBackward0>)
# tensor([[[8.9387]]], grad_fn=<AddBackward0>)
# tensor([[[14.5406]]], grad_fn=<AddBackward0>)
# tensor([[[12.8998]]], grad_fn=<AddBackward0>)
# tensor([[[15.5841]]], grad_fn=<AddBackward0>)
# tensor([[[10.2646]]], grad_fn=<AddBackward0>)
# tensor([[[12.0861]]], grad_fn=<AddBackward0>)
# tensor([[[7.5511]]], grad_fn=<AddBackward0>)
# tensor([[[10.3725]]], grad_fn=<AddBackward0>)
# tensor([[[10.9958]]], grad_fn=<AddBackward0>)
# tensor([[[12.9549]]], grad_fn=<AddBackward0>)
# tensor([[[11.6972]]], grad_fn=<AddBackward0>)
# tensor([[[9.1286]]], grad_fn=<AddBackward0>)
# tensor([[[12.1039]]], grad_fn=<AddBackward0>)
# tensor([[[14.1371]]], grad_fn=<AddBackward0>)
# tensor([[[7.1864]]], grad_fn=<AddBackward0>)
# tensor([[[13.1763]]], grad_fn=<AddBackward0>)
# tensor([[[11.1091]]], grad_fn=<AddBackward0>)
# tensor([[[18.6287]]], grad_fn=<AddBackward0>)
# tensor([[[11.3579]]], grad_fn=<AddBackward0>)
# tensor([[[11.4500]]], grad_fn=<AddBackward0>)
# tensor([[[9.0631]]], grad_fn=<AddBackward0>)
# tensor([[[11.6749]]], grad_fn=<AddBackward0>)
# tensor([[[13.2646]]], grad_fn=<AddBackward0>)
# tensor([[[12.3722]]], grad_fn=<AddBackward0>)
# tensor([[[12.1944]]], grad_fn=<AddBackward0>)
# tensor([[[13.9182]]], grad_fn=<AddBackward0>)
# tensor([[[8.5069]]], grad_fn=<AddBackward0>)
# tensor([[[12.5627]]], grad_fn=<AddBackward0>)
# tensor([[[14.4137]]], grad_fn=<AddBackward0>)
# tensor([[[12.9061]]], grad_fn=<AddBackward0>)
# tensor([[[10.5604]]], grad_fn=<AddBackward0>)
# tensor([[[15.1414]]], grad_fn=<AddBackward0>)
# tensor([[[12.8187]]], grad_fn=<AddBackward0>)
# tensor([[[8.7664]]], grad_fn=<AddBackward0>)
# tensor([[[10.4617]]], grad_fn=<AddBackward0>)
# tensor([[[9.9161]]], grad_fn=<AddBackward0>)
# tensor([[[10.7041]]], grad_fn=<AddBackward0>)
# tensor([[[12.9593]]], grad_fn=<AddBackward0>)
# tensor([[[9.2259]]], grad_fn=<AddBackward0>)
# tensor([[[8.2997]]], grad_fn=<AddBackward0>)
# tensor([[[13.3226]]], grad_fn=<AddBackward0>)
# tensor([[[10.5339]]], grad_fn=<AddBackward0>)
# tensor([[[8.7926]]], grad_fn=<AddBackward0>)
# tensor([[[8.8243]]], grad_fn=<AddBackward0>)
# tensor([[[8.0972]]], grad_fn=<AddBackward0>)
# tensor([[[12.9602]]], grad_fn=<AddBackward0>)
# tensor([[[8.3552]]], grad_fn=<AddBackward0>)
# tensor([[[10.8623]]], grad_fn=<AddBackward0>)
# tensor([[[11.7190]]], grad_fn=<AddBackward0>)
# tensor([[[11.2686]]], grad_fn=<AddBackward0>)
# tensor([[[10.5478]]], grad_fn=<AddBackward0>)
# tensor([[[7.5040]]], grad_fn=<AddBackward0>)
# tensor([[[9.8670]]], grad_fn=<AddBackward0>)
# tensor([[[7.0660]]], grad_fn=<AddBackward0>)
# tensor([[[7.2817]]], grad_fn=<AddBackward0>)
# tensor([[[7.0741]]], grad_fn=<AddBackward0>)
# tensor([[[7.4746]]], grad_fn=<AddBackward0>)
# tensor([[[6.8620]]], grad_fn=<AddBackward0>)
# tensor([[[9.0863]]], grad_fn=<AddBackward0>)
# tensor([[[9.4585]]], grad_fn=<AddBackward0>)
# tensor([[[9.2570]]], grad_fn=<AddBackward0>)
# tensor([[[12.5394]]], grad_fn=<AddBackward0>)
# tensor([[[7.0475]]], grad_fn=<AddBackward0>)
# tensor([[[7.1791]]], grad_fn=<AddBackward0>)
# tensor([[[14.6150]]], grad_fn=<AddBackward0>)
# tensor([[[14.4477]]], grad_fn=<AddBackward0>)
# tensor([[[13.6362]]], grad_fn=<AddBackward0>)
# tensor([[[10.4077]]], grad_fn=<AddBackward0>)
# tensor([[[11.0764]]], grad_fn=<AddBackward0>)
# tensor([[[13.3846]]], grad_fn=<AddBackward0>)
# tensor([[[16.6911]]], grad_fn=<AddBackward0>)
# tensor([[[8.2943]]], grad_fn=<AddBackward0>)
# tensor([[[11.7018]]], grad_fn=<AddBackward0>)
# tensor([[[8.1043]]], grad_fn=<AddBackward0>)
# tensor([[[10.9568]]], grad_fn=<AddBackward0>)
# tensor([[[7.5174]]], grad_fn=<AddBackward0>)
# tensor([[[12.8047]]], grad_fn=<AddBackward0>)
# tensor([[[8.1418]]], grad_fn=<AddBackward0>)
# tensor([[[11.3861]]], grad_fn=<AddBackward0>)
# tensor([[[10.2828]]], grad_fn=<AddBackward0>)
# tensor([[[10.7505]]], grad_fn=<AddBackward0>)
# tensor([[[11.2940]]], grad_fn=<AddBackward0>)
# tensor([[[12.3895]]], grad_fn=<AddBackward0>)
# tensor([[[15.5045]]], grad_fn=<AddBackward0>)
# tensor([[[17.9042]]], grad_fn=<AddBackward0>)
# tensor([[[12.8091]]], grad_fn=<AddBackward0>)
# tensor([[[13.8730]]], grad_fn=<AddBackward0>)
# tensor([[[13.3913]]], grad_fn=<AddBackward0>)
# tensor([[[9.8617]]], grad_fn=<AddBackward0>)
# tensor([[[12.1131]]], grad_fn=<AddBackward0>)
# tensor([[[17.0452]]], grad_fn=<AddBackward0>)
# tensor([[[7.3968]]], grad_fn=<AddBackward0>)
# tensor([[[17.4028]]], grad_fn=<AddBackward0>)
# tensor([[[9.6481]]], grad_fn=<AddBackward0>)
# tensor([[[13.7548]]], grad_fn=<AddBackward0>)
# tensor([[[11.7888]]], grad_fn=<AddBackward0>)
# tensor([[[10.4347]]], grad_fn=<AddBackward0>)
# tensor([[[17.3575]]], grad_fn=<AddBackward0>)
# tensor([[[15.5258]]], grad_fn=<AddBackward0>)
# tensor([[[15.2706]]], grad_fn=<AddBackward0>)
# tensor([[[8.6907]]], grad_fn=<AddBackward0>)
# tensor([[[8.3051]]], grad_fn=<AddBackward0>)
# tensor([[[10.1989]]], grad_fn=<AddBackward0>)
# tensor([[[13.2238]]], grad_fn=<AddBackward0>)
# tensor([[[8.2502]]], grad_fn=<AddBackward0>)
# tensor([[[10.1920]]], grad_fn=<AddBackward0>)
# tensor([[[11.1876]]], grad_fn=<AddBackward0>)
# tensor([[[14.0706]]], grad_fn=<AddBackward0>)
# tensor([[[10.4114]]], grad_fn=<AddBackward0>)
# tensor([[[11.2368]]], grad_fn=<AddBackward0>)
# tensor([[[10.2562]]], grad_fn=<AddBackward0>)
# tensor([[[12.9609]]], grad_fn=<AddBackward0>)
# tensor([[[11.4219]]], grad_fn=<AddBackward0>)
# tensor([[[10.2669]]], grad_fn=<AddBackward0>)
# tensor([[[17.2308]]], grad_fn=<AddBackward0>)
# tensor([[[8.2070]]], grad_fn=<AddBackward0>)
# tensor([[[11.9909]]], grad_fn=<AddBackward0>)
# tensor([[[18.8904]]], grad_fn=<AddBackward0>)
# tensor([[[11.0067]]], grad_fn=<AddBackward0>)
# tensor([[[12.0894]]], grad_fn=<AddBackward0>)
# tensor([[[10.5359]]], grad_fn=<AddBackward0>)
# tensor([[[7.9424]]], grad_fn=<AddBackward0>)
# tensor([[[8.0272]]], grad_fn=<AddBackward0>)
# tensor([[[9.0819]]], grad_fn=<AddBackward0>)
# tensor([[[8.2268]]], grad_fn=<AddBackward0>)
# tensor([[[8.5890]]], grad_fn=<AddBackward0>)
# tensor([[[13.5811]]], grad_fn=<AddBackward0>)
# tensor([[[8.0532]]], grad_fn=<AddBackward0>)
# tensor([[[10.3265]]], grad_fn=<AddBackward0>)
# tensor([[[8.5068]]], grad_fn=<AddBackward0>)
# tensor([[[12.4849]]], grad_fn=<AddBackward0>)
# tensor([[[12.4217]]], grad_fn=<AddBackward0>)
# tensor([[[10.6259]]], grad_fn=<AddBackward0>)
# tensor([[[13.0947]]], grad_fn=<AddBackward0>)
# tensor([[[12.5307]]], grad_fn=<AddBackward0>)
# tensor([[[8.3815]]], grad_fn=<AddBackward0>)
# tensor([[[9.5510]]], grad_fn=<AddBackward0>)
# tensor([[[7.6628]]], grad_fn=<AddBackward0>)
# tensor([[[8.6168]]], grad_fn=<AddBackward0>)
# tensor([[[10.2270]]], grad_fn=<AddBackward0>)
# tensor([[[8.2168]]], grad_fn=<AddBackward0>)
# tensor([[[10.9836]]], grad_fn=<AddBackward0>)
# tensor([[[7.3715]]], grad_fn=<AddBackward0>)
# tensor([[[8.1548]]], grad_fn=<AddBackward0>)
# tensor([[[9.7285]]], grad_fn=<AddBackward0>)
# tensor([[[9.4591]]], grad_fn=<AddBackward0>)
# tensor([[[8.6881]]], grad_fn=<AddBackward0>)
# tensor([[[7.3321]]], grad_fn=<AddBackward0>)
# tensor([[[9.0951]]], grad_fn=<AddBackward0>)
# tensor([[[11.8964]]], grad_fn=<AddBackward0>)
# tensor([[[10.3983]]], grad_fn=<AddBackward0>)
# tensor([[[7.2311]]], grad_fn=<AddBackward0>)
# tensor([[[7.1897]]], grad_fn=<AddBackward0>)
# tensor([[[12.6041]]], grad_fn=<AddBackward0>)
# tensor([[[8.8514]]], grad_fn=<AddBackward0>)
# tensor([[[10.2660]]], grad_fn=<AddBackward0>)
# tensor([[[12.2964]]], grad_fn=<AddBackward0>)
# tensor([[[7.5881]]], grad_fn=<AddBackward0>)
# tensor([[[7.1924]]], grad_fn=<AddBackward0>)
# tensor([[[14.6542]]], grad_fn=<AddBackward0>)
# tensor([[[7.5618]]], grad_fn=<AddBackward0>)
# tensor([[[7.5777]]], grad_fn=<AddBackward0>)
# tensor([[[7.5654]]], grad_fn=<AddBackward0>)
# tensor([[[16.3149]]], grad_fn=<AddBackward0>)
# tensor([[[12.5025]]], grad_fn=<AddBackward0>)
# tensor([[[8.7646]]], grad_fn=<AddBackward0>)
# tensor([[[8.1740]]], grad_fn=<AddBackward0>)
# tensor([[[7.8803]]], grad_fn=<AddBackward0>)
# tensor([[[7.0381]]], grad_fn=<AddBackward0>)
# tensor([[[10.4511]]], grad_fn=<AddBackward0>)
# tensor([[[11.1152]]], grad_fn=<AddBackward0>)
# tensor([[[8.0582]]], grad_fn=<AddBackward0>)
# tensor([[[7.2088]]], grad_fn=<AddBackward0>)
# tensor([[[7.7408]]], grad_fn=<AddBackward0>)
# tensor([[[9.7654]]], grad_fn=<AddBackward0>)
# tensor([[[10.4509]]], grad_fn=<AddBackward0>)
# tensor([[[12.7771]]], grad_fn=<AddBackward0>)
# tensor([[[8.8194]]], grad_fn=<AddBackward0>)
# tensor([[[9.7894]]], grad_fn=<AddBackward0>)
# tensor([[[12.9247]]], grad_fn=<AddBackward0>)
# tensor([[[13.3723]]], grad_fn=<AddBackward0>)
# tensor([[[13.2873]]], grad_fn=<AddBackward0>)
# tensor([[[10.7985]]], grad_fn=<AddBackward0>)
# tensor([[[14.4094]]], grad_fn=<AddBackward0>)
# tensor([[[9.8349]]], grad_fn=<AddBackward0>)
# tensor([[[10.1851]]], grad_fn=<AddBackward0>)
# tensor([[[12.5058]]], grad_fn=<AddBackward0>)
# tensor([[[12.6377]]], grad_fn=<AddBackward0>)
# tensor([[[11.9494]]], grad_fn=<AddBackward0>)
# tensor([[[15.6648]]], grad_fn=<AddBackward0>)
# tensor([[[13.6410]]], grad_fn=<AddBackward0>)
# tensor([[[12.2516]]], grad_fn=<AddBackward0>)
# tensor([[[14.7847]]], grad_fn=<AddBackward0>)
# tensor([[[11.7061]]], grad_fn=<AddBackward0>)
# tensor([[[11.8099]]], grad_fn=<AddBackward0>)
# tensor([[[15.2751]]], grad_fn=<AddBackward0>)
# tensor([[[14.4961]]], grad_fn=<AddBackward0>)
# tensor([[[14.7384]]], grad_fn=<AddBackward0>)
# tensor([[[11.1342]]], grad_fn=<AddBackward0>)
# tensor([[[13.5814]]], grad_fn=<AddBackward0>)
# tensor([[[13.8986]]], grad_fn=<AddBackward0>)
# tensor([[[9.8654]]], grad_fn=<AddBackward0>)
# tensor([[[10.4522]]], grad_fn=<AddBackward0>)
# tensor([[[8.2148]]], grad_fn=<AddBackward0>)
# tensor([[[14.4454]]], grad_fn=<AddBackward0>)
# tensor([[[12.2004]]], grad_fn=<AddBackward0>)
# tensor([[[11.9833]]], grad_fn=<AddBackward0>)
# tensor([[[8.9235]]], grad_fn=<AddBackward0>)
# tensor([[[7.9454]]], grad_fn=<AddBackward0>)
# tensor([[[7.9159]]], grad_fn=<AddBackward0>)
# tensor([[[8.9344]]], grad_fn=<AddBackward0>)
# tensor([[[12.5703]]], grad_fn=<AddBackward0>)
# tensor([[[6.7487]]], grad_fn=<AddBackward0>)
# tensor([[[12.2251]]], grad_fn=<AddBackward0>)
# tensor([[[9.2630]]], grad_fn=<AddBackward0>)
# tensor([[[10.4688]]], grad_fn=<AddBackward0>)
# tensor([[[10.6255]]], grad_fn=<AddBackward0>)
# tensor([[[8.0952]]], grad_fn=<AddBackward0>)
# tensor([[[11.4666]]], grad_fn=<AddBackward0>)
# tensor([[[13.0994]]], grad_fn=<AddBackward0>)
# step :  9 loss :  20.33234405517578

# %%
cProfile.run("dmodel(X[2],Y[0])", sort = "cumtime")
# Out:
#          1277250 function calls (1277242 primitive calls) in 8.788 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   11.659   11.659 {built-in method builtins.exec}
#         1    0.009    0.009   11.659   11.659 <string>:1(<module>)
#       9/1    0.000    0.000   11.650   11.650 module.py:715(_call_impl)
#         1    1.826    1.826   11.650   11.650 <ipython-input-181-258c63f1d29d>:23(forward)
#         2    0.002    0.001    9.758    4.879 <ipython-input-133-02d5852e0211>:5(alpha)
#       268    0.212    0.001    9.755    0.036 <ipython-input-133-02d5852e0211>:8(<listcomp>)
#    424440    0.525    0.000    5.221    0.000 <ipython-input-133-02d5852e0211>:1(att)
#    424440    2.643    0.000    2.643    0.000 {built-in method dot}
#    424440    2.053    0.000    2.053    0.000 {built-in method exp}
#      3144    1.453    0.000    1.453    0.000 {built-in method builtins.sum}
#         2    0.000    0.000    0.064    0.032 rnn.py:555(forward)
#         2    0.064    0.032    0.064    0.032 {built-in method lstm}
#         2    0.000    0.000    0.000    0.000 <ipython-input-181-258c63f1d29d>:10(forward)
#         2    0.000    0.000    0.000    0.000 linear.py:92(forward)
#         2    0.000    0.000    0.000    0.000 pooling.py:152(forward)
#         2    0.000    0.000    0.000    0.000 functional.py:1669(linear)
#         2    0.000    0.000    0.000    0.000 _jit_internal.py:257(fn)
#         2    0.000    0.000    0.000    0.000 functional.py:574(_max_pool2d)
#         2    0.000    0.000    0.000    0.000 {built-in method max_pool2d}
#         2    0.000    0.000    0.000    0.000 {method 'matmul' of 'torch._C._TensorBase' objects}
#         6    0.000    0.000    0.000    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 <ipython-input-181-258c63f1d29d>:7(__init__)
#         3    0.000    0.000    0.000    0.000 {built-in method cat}
#         4    0.000    0.000    0.000    0.000 module.py:223(__init__)
#        54    0.000    0.000    0.000    0.000 module.py:781(__setattr__)
#         2    0.000    0.000    0.000    0.000 {built-in method zeros}
#         2    0.000    0.000    0.000    0.000 pooling.py:17(__init__)
#         2    0.000    0.000    0.000    0.000 rnn.py:529(check_forward_args)
#       112    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         9    0.000    0.000    0.000    0.000 {built-in method torch._C._get_tracing_state}
#         2    0.000    0.000    0.000    0.000 {method 't' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 functional.py:1124(relu)
#        10    0.000    0.000    0.000    0.000 module.py:765(__getattr__)
#       160    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 overrides.py:1070(has_torch_function)
#         1    0.000    0.000    0.000    0.000 {built-in method relu}
#         2    0.000    0.000    0.000    0.000 rnn.py:171(check_input)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#        36    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method torch._C._log_api_usage_once}
#         2    0.000    0.000    0.000    0.000 _VF.py:25(__getattr__)
#         4    0.000    0.000    0.000    0.000 rnn.py:193(check_hidden_size)
#         6    0.000    0.000    0.000    0.000 overrides.py:1083(<genexpr>)
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 rnn.py:182(get_expected_hidden_size)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         4    0.000    0.000    0.000    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 functional.py:1686(<listcomp>)
#         2    0.000    0.000    0.000    0.000 module.py:782(remove_from)
#         2    0.000    0.000    0.000    0.000 rnn.py:538(permute_hidden)
#         5    0.000    0.000    0.000    0.000 _jit_internal.py:750(is_scripting)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method torch._C._is_torch_function_enabled}

# %%
import cProfile

# %%
# batch model definition
epochs = 10
n_features = 300
n_hidden = 100
batch_size = 32

class maxpool(nn.Module):
    def __init__(self, L):
        super(maxpool, self).__init__()
        self.maxpool = nn.MaxPool2d((L,2), stride=2)
    def forward(self, X):
        return self.maxpool(X)
    
def batch_att(G,H):
    P = alpha(G,H)@G
    inG = torch.cat((G,Q),1)
    return inG

class dnet(nn.Module):
    def __init__(self, n_features, D, FF):
        super(dnet, self).__init__()
    
        self.biLSTM_X = nn.LSTM(n_features, D, bidirectional=True)
        self.biLSTM_Y = nn.LSTM(n_features, D, bidirectional=True)
        
        self.FF = nn.Linear(4*D, FF)
        self.out = nn.Linear(FF, 1)
    
    def forward(self,X,Y):
        N = X.data.shape[0]
        M = Y.data.shape[0]
        
        #turn input list of vec into correct shape
        X = X.view(X.data.shape[0],1,X.data.shape[1]) #N rows
        Y = Y.view(Y.data.shape[0],1,Y.data.shape[1]) #M rows
        
        #biLSTM to get hidden states
        H, hcX = self.biLSTM_X(X, None) #NxBx2D matrix
        G, hcY = self.biLSTM_Y(Y, None) #MxBx2D matrix
        
        inG = torch.Tensor([batch_att(G[:,b,:],H[:,b,:]) for b in range(batch_size)])
        inH = torch.Tensor([batch_att(H[:,b,:],G[:,b,:]) for b in range(batch_size)])
        
        #maxpool concatenated tensors
        maxpool_X = maxpool(N)
        maxpool_Y = maxpool(M)
        u = maxpool_X(inH)  #1x1x2D
        v = maxpool_Y(inG)  #1x1x2D
        
        #feed forward neural network
        NN = torch.cat((u,v),2)
        NN = self.FF(NN)
        NN = nn.functional.relu(NN)
        output = self.out(NN)
        return output

dmodel = dnet(300,150,2000)
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(dmodel.parameters(), lr=0.0002, momentum=0.9, nesterov=True)

# %%
for t in range(epochs):
    for b in range(len(X)):
        solute = X[b]
        solvent = Y[0]
        target = targets[b]  

        output = dmodel(solute,solvent) 
        print(output)
        loss = criterion(output, target)  
        
        loss.backward()
        optimizer.step()        
        optimizer.zero_grad() 
    print('step : ' , t , 'loss : ' , loss.item())
